# %%
import random
from datetime import datetime, timedelta

# TABLA 1: Clientes
def generar_fecha_nacimiento():
    inicio = datetime(1970, 1, 1)
    fin = datetime(2000, 12, 31)
    return inicio + timedelta(days=random.randint(0, (fin - inicio).days))

clientes_data = []
for cliente_id in range(1, 201):  # 200 clientes
    sexo = random.choice(['M', 'F'])
    fecha_nacimiento = generar_fecha_nacimiento().strftime('%Y-%m-%d')
    ingreso_mensual = round(random.uniform(1500, 10000), 2)  # Ingresos entre 1,500 y 10,000
    # Cada registro: (ID_Cliente, Sexo, Fecha_Nacimiento, Ingreso)
    clientes_data.append((cliente_id, sexo, fecha_nacimiento, ingreso_mensual))

# %%
# TABLA 2: Solicitudes de Crédito
solicitudes_data = []
for cliente_id, _, _, ingreso in clientes_data:
    monto_maximo = ingreso * 5  # El cliente puede solicitar hasta 5 veces su ingreso
    monto_solicitado = round(random.uniform(1000, min(monto_maximo, 50000)), 2)
    plazo_meses = random.choice([12, 24, 36, 48, 60])
    # La tasa se ajusta: menor ingreso → tasa mayor; se resta un valor proporcional al ingreso
    tasa_interes = round(random.uniform(5.0, 20.0) - (ingreso / 5000) * 3, 2)
    tasa_interes = max(3.5, tasa_interes)  # Límite mínimo de 3.5%
    # Cada registro: (ID_Cliente, Monto_Solicitado, Plazo_Meses, Tasa_Interes)
    solicitudes_data.append((cliente_id, monto_solicitado, plazo_meses, tasa_interes))

# %%
# TABLA 3: Evaluaciones de Riesgo
evaluaciones_data = []
estados_solicitud = []  # Almacenará (ID_Solicitud, Estado)
for idx, (id_cliente, monto, plazo, tasa) in enumerate(solicitudes_data, start=1):
    # Buscar ingreso del cliente (en clientes_data, ingreso está en posición 3)
    ingreso_cliente = [c[3] for c in clientes_data if c[0] == id_cliente][0]
    # Calcular score en función del ingreso:
    # El score se escala entre 300 y 900: mayor ingreso → score más alto
    score_riesgo = min(900, max(300, int((ingreso_cliente / 10000) * 600 + 300)))
    if score_riesgo >= 750:
        nivel_riesgo = 'Bajo'
    elif score_riesgo >= 500:
        nivel_riesgo = 'Medio'
    else:
        nivel_riesgo = 'Alto'
    comentarios = f"Evaluación de riesgo: {nivel_riesgo}."
    # Cada registro: (ID_Solicitud, Score_Riesgo, Nivel_Riesgo, Comentarios)
    evaluaciones_data.append((idx, score_riesgo, nivel_riesgo, estado, comentarios))

    # Determinar estado de la solicitud basado en el nivel de riesgo
    if nivel_riesgo == 'Bajo':
        estado = 'Aprobado'
    elif nivel_riesgo == 'Medio':
        estado = random.choices(['Aprobado', 'Pendiente'], weights=[0.6, 0.4])[0]
    else:
        estado = 'Rechazado'
    estados_solicitud.append((idx, estado))

# %%
# TABLA 4: Pagos
pagos_data = []
for id_solicitud, estado in estados_solicitud:
    if estado == 'Aprobado':
        num_pagos = random.randint(1, 12)  # Entre 1 y 12 pagos registrados
        for _ in range(num_pagos):
            monto_pagado = round(random.uniform(100, 2000), 2)
            metodo_pago = random.choice(['Transferencia', 'Tarjeta', 'Efectivo'])
            # Cada registro: (ID_Solicitud, Monto_Pagado, Método_Pago)
            pagos_data.append((id_solicitud, monto_pagado, metodo_pago))

# %%
# TABLA 5: Historial Crediticio
historial_crediticio_data = []
for cliente_id in range(1, 201):
    cantidad_prestamos = random.randint(0, 5)  # Entre 0 y 5 préstamos previos
    monto_total = round(random.uniform(1000, 100000), 2) if cantidad_prestamos > 0 else 0
    historial_pagos = random.choices(['Bueno', 'Regular', 'Malo'], weights=[0.6, 0.3, 0.1])[0] if cantidad_prestamos > 0 else 'Bueno'
    # Cada registro: (ID_Cliente, Monto_Total, Cantidad_Prestamos, Historial_Pagos)
    historial_crediticio_data.append((cliente_id, monto_total, cantidad_prestamos, historial_pagos))

# %%
# Mostrar resultados
print("Tabla 1: Clientes")
for row in clientes_data:
    print(f"{row},")

print("\nTabla 2: Solicitudes de crédito")
for row in solicitudes_data:
    print(f"{row},")

print("\nTabla 3: Evaluaciones de riesgo")
for row in evaluaciones_data:
    print(f"{row},")

print("\nTabla 4: Pagos")
for row in pagos_data:
    print(f"{row},")

print("\nTabla 5: Historial crediticio")
for row in historial_crediticio_data:
    print(f"{row},")
# Out:
# Tabla 1: Clientes
# (1, 'M', '1982-01-31', 3028.36),
# (2, 'M', '1995-05-06', 6632.9),
# (3, 'F', '1978-11-05', 3931.91),
# (4, 'F', '1979-08-01', 2042.62),
# (5, 'F', '1978-12-04', 6361.24),
# (6, 'M', '1991-11-26', 3514.04),
# (7, 'M', '1997-08-30', 5830.27),
# (8, 'M', '1973-05-08', 6518.75),
# (9, 'F', '1976-01-31', 6797.71),
# (10, 'F', '1995-01-29', 9387.2),
# (11, 'F', '1984-06-19', 9248.46),
# (12, 'M', '1989-04-17', 5846.45),
# (13, 'F', '1990-07-19', 4890.79),
# (14, 'M', '1992-12-26', 5140.04),
# (15, 'F', '1972-03-30', 8177.01),
# (16, 'F', '1985-12-19', 4841.9),
# (17, 'F', '1984-03-13', 3123.88),
# (18, 'F', '1970-05-26', 2889.62),
# (19, 'M', '1993-11-09', 3721.84),
# (20, 'M', '1974-12-26', 4294.74),
# (21, 'F', '1994-02-12', 6550.4),
# (22, 'F', '1984-12-16', 9370.03),
# (23, 'F', '1981-08-18', 4156.47),
# (24, 'F', '1991-04-27', 9035.8),
# (25, 'F', '1973-03-26', 8607.6),
# (26, 'M', '1987-05-11', 5270.7),
# (27, 'M', '1977-10-22', 5778.15),
# (28, 'F', '1984-02-03', 2916.57),
# (29, 'M', '1982-07-17', 6685.04),
# (30, 'M', '1991-12-09', 6793.65),
# (31, 'F', '1983-03-22', 3558.52),
# (32, 'M', '1972-01-25', 9342.63),
# (33, 'M', '2000-03-27', 6687.92),
# (34, 'F', '1975-02-18', 5552.87),
# (35, 'M', '1978-07-08', 5893.58),
# (36, 'F', '1986-11-29', 3871.57),
# (37, 'M', '1981-06-04', 6980.09),
# (38, 'F', '1974-10-27', 6449.29),
# (39, 'M', '1988-05-04', 9268.32),
# (40, 'F', '1996-04-07', 4697.41),
# (41, 'F', '1972-01-03', 4454.33),
# (42, 'M', '1978-07-13', 4408.53),
# (43, 'F', '1977-06-19', 3576.84),
# (44, 'M', '1980-04-18', 3803.7),
# (45, 'M', '1979-08-10', 8379.37),
# (46, 'M', '1976-08-05', 5386.01),
# (47, 'F', '1996-12-23', 6736.77),
# (48, 'M', '1988-02-28', 8490.33),
# (49, 'F', '1985-04-10', 7637.73),
# (50, 'F', '1977-03-09', 9871.56),
# (51, 'M', '1985-06-01', 9155.67),
# (52, 'F', '1972-01-19', 6537.27),
# (53, 'M', '1972-07-22', 4257.72),
# (54, 'F', '1974-09-28', 8560.14),
# (55, 'M', '1982-11-20', 9946.05),
# (56, 'F', '1987-10-03', 2611.96),
# (57, 'F', '1972-09-13', 8630.22),
# (58, 'M', '1991-01-11', 4630.2),
# (59, 'M', '1985-09-01', 8742.27),
# (60, 'M', '1985-05-15', 8661.31),
# (61, 'F', '1978-02-19', 6591.43),
# (62, 'M', '1994-09-18', 5215.18),
# (63, 'M', '1983-06-14', 8946.71),
# (64, 'F', '1971-06-09', 5993.32),
# (65, 'M', '1990-07-01', 7317.92),
# (66, 'F', '1985-04-08', 9643.79),
# (67, 'F', '1988-03-05', 6205.99),
# (68, 'M', '1980-02-16', 5916.51),
# (69, 'F', '1998-09-04', 5473.16),
# (70, 'M', '1973-05-03', 7209.75),
# (71, 'M', '1970-09-28', 3574.93),
# (72, 'F', '1973-04-06', 1932.76),
# (73, 'M', '1977-07-12', 9463.68),
# (74, 'M', '1984-02-16', 6873.21),
# (75, 'M', '1979-05-26', 4457.34),
# (76, 'F', '1993-07-19', 1912.52),
# (77, 'M', '1998-10-20', 6170.97),
# (78, 'M', '1987-05-16', 9554.05),
# (79, 'M', '1982-11-09', 3004.56),
# (80, 'F', '1990-08-14', 4588.66),
# (81, 'M', '1974-04-18', 7329.27),
# (82, 'M', '1979-06-22', 9402.7),
# (83, 'F', '1994-06-06', 9675.86),
# (84, 'F', '1979-04-14', 2819.3),
# (85, 'M', '1978-05-14', 3086.41),
# (86, 'M', '1976-11-29', 8208.28),
# (87, 'F', '1989-03-23', 3997.62),
# (88, 'F', '1992-02-06', 2511.7),
# (89, 'F', '1985-10-24', 3530.56),
# (90, 'F', '1976-10-28', 6865.88),
# (91, 'M', '1985-11-13', 4703.51),
# (92, 'F', '1994-03-04', 3616.1),
# (93, 'F', '1991-08-13', 5402.77),
# (94, 'M', '1983-06-28', 2567.25),
# (95, 'F', '1997-07-08', 1621.25),
# (96, 'F', '1974-10-02', 7593.51),
# (97, 'M', '1984-07-19', 3454.68),
# (98, 'F', '1999-07-18', 9636.95),
# (99, 'F', '1981-12-13', 9202.49),
# (100, 'F', '1995-12-10', 6427.12),
# (101, 'M', '1988-05-07', 5077.91),
# (102, 'F', '1979-09-22', 9387.55),
# (103, 'F', '1987-03-19', 6817.17),
# (104, 'F', '1989-08-16', 7477.6),
# (105, 'M', '1972-02-26', 3334.88),
# (106, 'M', '1976-12-01', 8650.12),
# (107, 'F', '1978-10-30', 1875.88),
# (108, 'F', '1982-02-28', 7026.04),
# (109, 'F', '1978-10-06', 5102.0),
# (110, 'M', '1989-10-11', 3957.96),
# (111, 'M', '1987-09-20', 6760.64),
# (112, 'M', '1977-01-31', 5163.17),
# (113, 'F', '1993-06-26', 9465.68),
# (114, 'F', '1996-09-20', 7887.18),
# (115, 'M', '1972-01-24', 9981.72),
# (116, 'F', '2000-05-22', 3750.76),
# (117, 'F', '1995-05-04', 6430.52),
# (118, 'M', '1978-11-18', 9014.57),
# (119, 'M', '1995-12-11', 9157.06),
# (120, 'M', '1978-07-03', 9623.16),
# (121, 'F', '1991-02-12', 5931.98),
# (122, 'M', '1970-07-17', 5116.51),
# (123, 'F', '1981-03-28', 3063.84),
# (124, 'M', '1973-09-20', 6387.1),
# (125, 'M', '1982-06-08', 4390.55),
# (126, 'M', '1997-03-29', 4314.6),
# (127, 'F', '1970-06-17', 2850.94),
# (128, 'M', '1973-02-20', 4408.98),
# (129, 'M', '1976-11-21', 8666.11),
# (130, 'M', '1980-11-12', 1752.38),
# (131, 'F', '1986-09-27', 3883.33),
# (132, 'F', '1972-08-30', 7987.39),
# (133, 'M', '1997-11-01', 6259.71),
# (134, 'M', '1991-04-01', 5594.45),
# (135, 'F', '1993-10-04', 7231.15),
# (136, 'F', '1971-02-07', 3563.39),
# (137, 'M', '1970-12-26', 8963.92),
# (138, 'M', '1986-01-18', 2077.29),
# (139, 'M', '1973-09-03', 3605.65),
# (140, 'M', '1988-02-12', 3825.16),
# (141, 'F', '1997-10-30', 9610.13),
# (142, 'M', '1973-01-25', 4952.67),
# (143, 'F', '1992-11-13', 6471.64),
# (144, 'M', '1985-01-04', 3278.18),
# (145, 'F', '1985-12-28', 3166.84),
# (146, 'M', '1982-07-27', 5275.26),
# (147, 'M', '1973-07-16', 4815.39),
# (148, 'M', '1986-12-26', 2656.31),
# (149, 'F', '1974-10-09', 2317.95),
# (150, 'M', '1993-04-11', 1942.47),
# (151, 'F', '2000-04-03', 6948.87),
# (152, 'F', '1970-02-28', 2747.92),
# (153, 'F', '1970-06-01', 6104.59),
# (154, 'F', '1974-10-12', 6722.46),
# (155, 'F', '1971-10-21', 5694.05),
# (156, 'M', '1998-03-19', 2573.4),
# (157, 'M', '1981-12-28', 5975.86),
# (158, 'M', '1971-05-31', 5529.03),
# (159, 'F', '1992-08-11', 4642.95),
# (160, 'F', '1980-09-05', 3950.16),
# (161, 'M', '1992-06-19', 4567.79),
# (162, 'M', '1995-03-07', 6914.24),
# (163, 'F', '1990-05-31', 8817.04),
# (164, 'F', '1991-12-12', 4815.7),
# (165, 'F', '1989-05-31', 5967.14),
# (166, 'M', '1995-01-25', 9497.35),
# (167, 'F', '1997-06-28', 2931.89),
# (168, 'F', '1971-05-12', 7453.83),
# (169, 'M', '1979-09-07', 1675.75),
# (170, 'F', '1989-10-02', 8853.47),
# (171, 'M', '1991-06-16', 1599.93),
# (172, 'M', '1971-04-21', 8178.18),
# (173, 'M', '1991-09-16', 9735.39),
# (174, 'F', '1973-01-21', 7729.89),
# (175, 'F', '1981-06-25', 6840.27),
# (176, 'F', '1996-11-04', 5112.17),
# (177, 'F', '1972-07-26', 6288.63),
# (178, 'F', '1987-11-04', 6498.59),
# (179, 'F', '1995-03-09', 2183.9),
# (180, 'M', '1981-12-07', 9965.34),
# (181, 'F', '1984-01-27', 4835.01),
# (182, 'F', '1993-08-18', 2250.54),
# (183, 'M', '1981-10-22', 1598.95),
# (184, 'F', '1975-02-09', 3328.87),
# (185, 'M', '1994-07-02', 2577.02),
# (186, 'F', '1985-05-31', 2775.05),
# (187, 'F', '1986-09-25', 7397.59),
# (188, 'F', '1993-04-06', 7702.67),
# (189, 'F', '1980-07-17', 8405.47),
# (190, 'F', '2000-10-07', 6203.87),
# (191, 'M', '1970-07-20', 8571.1),
# (192, 'F', '1974-04-27', 7096.9),
# (193, 'F', '1971-10-15', 7926.63),
# (194, 'F', '1983-09-20', 1866.53),
# (195, 'M', '1979-05-19', 6174.34),
# (196, 'M', '1993-09-01', 2610.81),
# (197, 'F', '2000-12-30', 5694.2),
# (198, 'F', '1975-10-19', 3276.93),
# (199, 'M', '1989-11-05', 7196.04),
# (200, 'M', '1983-08-24', 7210.61),
#
# Tabla 2: Solicitudes de crédito
# (1, 9927.86, 12, 11.94),
# (2, 11279.15, 24, 9.36),
# (3, 6546.98, 12, 9.37),
# (4, 17216.16, 60, 7.17),
# (5, 1851.29, 12, 5.58),
# (6, 5406.51, 48, 8.86),
# (7, 5995.69, 24, 11.34),
# (8, 23163.81, 36, 13.25),
# (9, 27709.31, 12, 5.79),
# (10, 11886.36, 36, 5.76),
# (11, 31891.12, 12, 10.49),
# (12, 28410.96, 60, 3.5),
# (13, 18704.99, 48, 9.68),
# (14, 4885.86, 36, 16.83),
# (15, 27339.76, 60, 14.92),
# (16, 3747.76, 60, 9.58),
# (17, 23804.6, 48, 12.85),
# (18, 25104.97, 48, 3.5),
# (19, 20809.38, 60, 7.14),
# (20, 14881.8, 12, 15.92),
# (21, 26172.44, 24, 6.9),
# (22, 22723.24, 12, 9.6),
# (23, 1332.24, 12, 13.48),
# (24, 7499.4, 48, 14.73),
# (25, 8993.63, 48, 4.7),
# (26, 4055.37, 24, 13.9),
# (27, 21341.44, 24, 7.58),
# (28, 2305.89, 48, 5.3),
# (29, 5713.96, 36, 16.65),
# (30, 9024.73, 24, 6.31),
# (31, 21236.68, 48, 14.79),
# (32, 10352.82, 24, 8.19),
# (33, 12885.35, 24, 3.5),
# (34, 16597.34, 60, 12.89),
# (35, 6342.38, 36, 4.99),
# (36, 20710.68, 36, 6.45),
# (37, 34609.93, 24, 13.43),
# (38, 4205.96, 24, 10.0),
# (39, 36650.92, 24, 4.27),
# (40, 7298.16, 24, 9.33),
# (41, 6626.47, 36, 3.9),
# (42, 10981.24, 12, 3.5),
# (43, 29738.0, 48, 12.85),
# (44, 6393.05, 24, 3.58),
# (45, 19320.97, 48, 12.97),
# (46, 18239.44, 48, 9.14),
# (47, 1896.18, 60, 14.64),
# (48, 18030.22, 12, 6.23),
# (49, 24782.18, 60, 7.28),
# (50, 23451.87, 12, 13.07),
# (51, 16682.27, 12, 11.38),
# (52, 11221.53, 12, 16.31),
# (53, 21419.88, 48, 10.68),
# (54, 27791.41, 24, 3.5),
# (55, 21647.54, 60, 3.5),
# (56, 24347.79, 36, 6.01),
# (57, 17461.16, 48, 16.09),
# (58, 3888.3, 48, 10.62),
# (59, 15970.91, 60, 9.3),
# (60, 12074.14, 24, 3.5),
# (61, 4271.15, 60, 5.84),
# (62, 4750.6, 60, 5.12),
# (63, 1316.24, 36, 4.15),
# (64, 1676.93, 36, 7.28),
# (65, 25176.75, 48, 5.41),
# (66, 8819.36, 36, 16.32),
# (67, 17608.43, 24, 12.19),
# (68, 5437.05, 24, 11.37),
# (69, 10658.27, 48, 8.1),
# (70, 38026.44, 60, 5.42),
# (71, 4302.94, 24, 10.12),
# (72, 13227.3, 60, 15.13),
# (73, 18729.65, 60, 3.82),
# (74, 4571.94, 24, 12.27),
# (75, 17368.47, 12, 3.68),
# (76, 35630.33, 12, 7.68),
# (77, 10156.2, 36, 14.07),
# (78, 4196.83, 12, 14.18),
# (79, 12627.06, 24, 4.92),
# (80, 18799.25, 24, 10.96),
# (81, 8210.92, 48, 6.62),
# (82, 13597.32, 24, 4.26),
# (83, 10244.01, 60, 8.26),
# (84, 17350.92, 36, 8.79),
# (85, 23883.0, 24, 14.85),
# (86, 4812.14, 48, 5.93),
# (87, 11961.1, 60, 8.2),
# (88, 11970.24, 60, 13.72),
# (89, 22563.5, 60, 6.66),
# (90, 15808.25, 60, 10.97),
# (91, 4278.77, 48, 15.13),
# (92, 6807.48, 60, 14.64),
# (93, 7416.34, 48, 9.11),
# (94, 5349.31, 48, 5.94),
# (95, 17932.88, 12, 7.68),
# (96, 18601.4, 36, 9.76),
# (97, 11611.0, 36, 13.82),
# (98, 19721.91, 12, 11.15),
# (99, 29046.78, 48, 3.5),
# (100, 7036.72, 36, 4.08),
# (101, 6365.0, 48, 13.81),
# (102, 9514.25, 24, 8.75),
# (103, 3062.11, 36, 5.88),
# (104, 16670.97, 12, 3.5),
# (105, 1330.26, 48, 3.5),
# (106, 30181.95, 36, 14.17),
# (107, 12291.86, 36, 18.29),
# (108, 1045.18, 48, 6.54),
# (109, 27754.44, 60, 5.63),
# (110, 21373.82, 24, 13.99),
# (111, 24313.79, 48, 4.76),
# (112, 3797.48, 36, 8.26),
# (113, 14267.46, 36, 12.47),
# (114, 13840.32, 12, 3.5),
# (115, 30351.07, 36, 13.54),
# (116, 14230.55, 48, 9.33),
# (117, 6656.66, 24, 7.2),
# (118, 5390.71, 48, 4.82),
# (119, 35249.6, 24, 3.5),
# (120, 4588.0, 12, 9.47),
# (121, 22281.73, 60, 13.55),
# (122, 10823.02, 36, 7.47),
# (123, 17040.11, 60, 9.07),
# (124, 10193.59, 24, 6.3),
# (125, 10636.16, 12, 3.5),
# (126, 11514.85, 24, 11.27),
# (127, 3133.43, 60, 14.01),
# (128, 7776.38, 12, 5.95),
# (129, 1065.48, 60, 14.92),
# (130, 10506.0, 48, 11.83),
# (131, 8754.8, 48, 8.53),
# (132, 11304.68, 24, 6.29),
# (133, 4176.38, 60, 3.5),
# (134, 16066.56, 60, 6.36),
# (135, 7153.67, 48, 7.05),
# (136, 4282.14, 48, 9.76),
# (137, 22500.72, 24, 15.77),
# (138, 14236.55, 24, 3.5),
# (139, 14037.58, 36, 16.29),
# (140, 8716.18, 48, 3.5),
# (141, 17590.43, 36, 3.5),
# (142, 1052.48, 24, 10.18),
# (143, 10634.68, 24, 6.7),
# (144, 15247.64, 60, 6.64),
# (145, 12366.49, 60, 12.43),
# (146, 17016.14, 24, 3.5),
# (147, 17714.51, 24, 14.69),
# (148, 8181.52, 60, 3.5),
# (149, 8520.7, 48, 8.16),
# (150, 8507.62, 48, 14.92),
# (151, 37128.18, 60, 4.33),
# (152, 1403.79, 48, 3.5),
# (153, 3679.92, 60, 12.71),
# (154, 18242.91, 60, 3.5),
# (155, 17781.78, 36, 3.5),
# (156, 5530.4, 48, 3.5),
# (157, 8555.24, 24, 15.13),
# (158, 43236.67, 48, 10.62),
# (159, 18795.85, 36, 13.28),
# (160, 7650.85, 24, 6.65),
# (161, 23223.61, 12, 9.32),
# (162, 24447.45, 60, 5.13),
# (163, 12439.0, 12, 6.86),
# (164, 23398.82, 12, 14.07),
# (165, 2035.03, 24, 3.5),
# (166, 10079.49, 60, 11.4),
# (167, 33833.37, 60, 3.5),
# (168, 9206.82, 60, 6.63),
# (169, 12516.2, 48, 6.87),
# (170, 19717.53, 48, 14.47),
# (171, 5360.15, 60, 4.07),
# (172, 16702.95, 12, 5.36),
# (173, 3348.97, 12, 11.37),
# (174, 12065.05, 36, 3.5),
# (175, 8126.47, 48, 4.18),
# (176, 6338.38, 36, 10.14),
# (177, 12975.01, 36, 6.2),
# (178, 6309.29, 60, 3.5),
# (179, 3709.39, 24, 9.22),
# (180, 8020.94, 12, 8.09),
# (181, 7561.38, 36, 8.81),
# (182, 23505.53, 12, 5.16),
# (183, 43147.89, 36, 3.5),
# (184, 44024.6, 60, 4.14),
# (185, 21305.53, 36, 8.65),
# (186, 8779.92, 36, 7.85),
# (187, 4883.81, 48, 3.86),
# (188, 15868.48, 36, 9.14),
# (189, 43397.05, 36, 3.5),
# (190, 6995.69, 36, 4.4),
# (191, 6726.92, 36, 6.28),
# (192, 15661.32, 48, 16.37),
# (193, 2596.37, 48, 3.5),
# (194, 8987.93, 24, 8.32),
# (195, 24423.27, 48, 3.5),
# (196, 7180.88, 60, 3.5),
# (197, 6216.32, 48, 4.97),
# (198, 8902.92, 36, 5.7),
# (199, 2472.47, 48, 4.93),
# (200, 21354.0, 60, 8.63),
#
# Tabla 3: Evaluaciones de riesgo
# (1, 432, 'Alto', 'Aprobado', 'Evaluación de riesgo: Alto.'),
# (2, 519, 'Medio', 'Rechazado', 'Evaluación de riesgo: Medio.'),
# (3, 407, 'Alto', 'Pendiente', 'Evaluación de riesgo: Alto.'),
# (4, 578, 'Medio', 'Rechazado', 'Evaluación de riesgo: Medio.'),
# (5, 416, 'Alto', 'Pendiente', 'Evaluación de riesgo: Alto.'),
# (6, 390, 'Alto', 'Rechazado', 'Evaluación de riesgo: Alto.'),
# (7, 534, 'Medio', 'Rechazado', 'Evaluación de riesgo: Medio.'),
# (8, 868, 'Bajo', 'Pendiente', 'Evaluación de riesgo: Bajo.'),
# (9, 685, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (10, 853, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (11, 763, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (12, 756, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (13, 556, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (14, 473, 'Alto', 'Aprobado', 'Evaluación de riesgo: Alto.'),
# (15, 725, 'Medio', 'Rechazado', 'Evaluación de riesgo: Medio.'),
# (16, 701, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (17, 732, 'Medio', 'Pendiente', 'Evaluación de riesgo: Medio.'),
# (18, 736, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (19, 736, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (20, 574, 'Medio', 'Pendiente', 'Evaluación de riesgo: Medio.'),
# (21, 623, 'Medio', 'Pendiente', 'Evaluación de riesgo: Medio.'),
# (22, 844, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (23, 696, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (24, 740, 'Medio', 'Pendiente', 'Evaluación de riesgo: Medio.'),
# (25, 639, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (26, 553, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (27, 730, 'Medio', 'Pendiente', 'Evaluación de riesgo: Medio.'),
# (28, 435, 'Alto', 'Pendiente', 'Evaluación de riesgo: Alto.'),
# (29, 392, 'Alto', 'Rechazado', 'Evaluación de riesgo: Alto.'),
# (30, 873, 'Bajo', 'Rechazado', 'Evaluación de riesgo: Bajo.'),
# (31, 625, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (32, 558, 'Medio', 'Pendiente', 'Evaluación de riesgo: Medio.'),
# (33, 776, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (34, 713, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (35, 458, 'Alto', 'Pendiente', 'Evaluación de riesgo: Alto.'),
# (36, 711, 'Medio', 'Rechazado', 'Evaluación de riesgo: Medio.'),
# (37, 761, 'Bajo', 'Pendiente', 'Evaluación de riesgo: Bajo.'),
# (38, 438, 'Alto', 'Aprobado', 'Evaluación de riesgo: Alto.'),
# (39, 866, 'Bajo', 'Rechazado', 'Evaluación de riesgo: Bajo.'),
# (40, 543, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (41, 569, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (42, 695, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (43, 742, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (44, 722, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (45, 577, 'Medio', 'Pendiente', 'Evaluación de riesgo: Medio.'),
# (46, 525, 'Medio', 'Pendiente', 'Evaluación de riesgo: Medio.'),
# (47, 714, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (48, 627, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (49, 764, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (50, 839, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (51, 607, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (52, 441, 'Alto', 'Pendiente', 'Evaluación de riesgo: Alto.'),
# (53, 676, 'Medio', 'Rechazado', 'Evaluación de riesgo: Medio.'),
# (54, 726, 'Medio', 'Pendiente', 'Evaluación de riesgo: Medio.'),
# (55, 889, 'Bajo', 'Pendiente', 'Evaluación de riesgo: Bajo.'),
# (56, 669, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (57, 558, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (58, 890, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (59, 888, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (60, 846, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (61, 780, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (62, 435, 'Alto', 'Aprobado', 'Evaluación de riesgo: Alto.'),
# (63, 828, 'Bajo', 'Rechazado', 'Evaluación de riesgo: Bajo.'),
# (64, 475, 'Alto', 'Aprobado', 'Evaluación de riesgo: Alto.'),
# (65, 645, 'Medio', 'Rechazado', 'Evaluación de riesgo: Medio.'),
# (66, 439, 'Alto', 'Aprobado', 'Evaluación de riesgo: Alto.'),
# (67, 560, 'Medio', 'Rechazado', 'Evaluación de riesgo: Medio.'),
# (68, 802, 'Bajo', 'Pendiente', 'Evaluación de riesgo: Bajo.'),
# (69, 442, 'Alto', 'Aprobado', 'Evaluación de riesgo: Alto.'),
# (70, 838, 'Bajo', 'Rechazado', 'Evaluación de riesgo: Bajo.'),
# (71, 457, 'Alto', 'Aprobado', 'Evaluación de riesgo: Alto.'),
# (72, 460, 'Alto', 'Rechazado', 'Evaluación de riesgo: Alto.'),
# (73, 718, 'Medio', 'Rechazado', 'Evaluación de riesgo: Medio.'),
# (74, 607, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (75, 540, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (76, 870, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (77, 448, 'Alto', 'Aprobado', 'Evaluación de riesgo: Alto.'),
# (78, 756, 'Bajo', 'Rechazado', 'Evaluación de riesgo: Bajo.'),
# (79, 838, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (80, 580, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (81, 693, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (82, 531, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (83, 434, 'Alto', 'Aprobado', 'Evaluación de riesgo: Alto.'),
# (84, 751, 'Bajo', 'Rechazado', 'Evaluación de riesgo: Bajo.'),
# (85, 597, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (86, 896, 'Bajo', 'Pendiente', 'Evaluación de riesgo: Bajo.'),
# (87, 517, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (88, 814, 'Bajo', 'Pendiente', 'Evaluación de riesgo: Bajo.'),
# (89, 686, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (90, 736, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (91, 417, 'Alto', 'Aprobado', 'Evaluación de riesgo: Alto.'),
# (92, 759, 'Bajo', 'Rechazado', 'Evaluación de riesgo: Bajo.'),
# (93, 580, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (94, 392, 'Alto', 'Aprobado', 'Evaluación de riesgo: Alto.'),
# (95, 641, 'Medio', 'Rechazado', 'Evaluación de riesgo: Medio.'),
# (96, 597, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (97, 586, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (98, 713, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (99, 798, 'Bajo', 'Pendiente', 'Evaluación de riesgo: Bajo.'),
# (100, 553, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (101, 395, 'Alto', 'Aprobado', 'Evaluación de riesgo: Alto.'),
# (102, 436, 'Alto', 'Rechazado', 'Evaluación de riesgo: Alto.'),
# (103, 673, 'Medio', 'Rechazado', 'Evaluación de riesgo: Medio.'),
# (104, 577, 'Medio', 'Pendiente', 'Evaluación de riesgo: Medio.'),
# (105, 797, 'Bajo', 'Pendiente', 'Evaluación de riesgo: Bajo.'),
# (106, 874, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (107, 458, 'Alto', 'Aprobado', 'Evaluación de riesgo: Alto.'),
# (108, 390, 'Alto', 'Rechazado', 'Evaluación de riesgo: Alto.'),
# (109, 677, 'Medio', 'Rechazado', 'Evaluación de riesgo: Medio.'),
# (110, 845, 'Bajo', 'Pendiente', 'Evaluación de riesgo: Bajo.'),
# (111, 634, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (112, 652, 'Medio', 'Pendiente', 'Evaluación de riesgo: Medio.'),
# (113, 629, 'Medio', 'Pendiente', 'Evaluación de riesgo: Medio.'),
# (114, 882, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (115, 695, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (116, 698, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (117, 734, 'Medio', 'Pendiente', 'Evaluación de riesgo: Medio.'),
# (118, 497, 'Alto', 'Aprobado', 'Evaluación de riesgo: Alto.'),
# (119, 736, 'Medio', 'Rechazado', 'Evaluación de riesgo: Medio.'),
# (120, 597, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (121, 803, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (122, 547, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (123, 737, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (124, 492, 'Alto', 'Aprobado', 'Evaluación de riesgo: Alto.'),
# (125, 787, 'Bajo', 'Rechazado', 'Evaluación de riesgo: Bajo.'),
# (126, 518, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (127, 407, 'Alto', 'Pendiente', 'Evaluación de riesgo: Alto.'),
# (128, 583, 'Medio', 'Rechazado', 'Evaluación de riesgo: Medio.'),
# (129, 406, 'Alto', 'Pendiente', 'Evaluación de riesgo: Alto.'),
# (130, 722, 'Medio', 'Rechazado', 'Evaluación de riesgo: Medio.'),
# (131, 496, 'Alto', 'Aprobado', 'Evaluación de riesgo: Alto.'),
# (132, 838, 'Bajo', 'Rechazado', 'Evaluación de riesgo: Bajo.'),
# (133, 775, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (134, 723, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (135, 394, 'Alto', 'Aprobado', 'Evaluación de riesgo: Alto.'),
# (136, 470, 'Alto', 'Rechazado', 'Evaluación de riesgo: Alto.'),
# (137, 660, 'Medio', 'Rechazado', 'Evaluación de riesgo: Medio.'),
# (138, 710, 'Medio', 'Pendiente', 'Evaluación de riesgo: Medio.'),
# (139, 573, 'Medio', 'Pendiente', 'Evaluación de riesgo: Medio.'),
# (140, 636, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (141, 547, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (142, 779, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (143, 549, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (144, 887, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (145, 574, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (146, 860, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (147, 674, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (148, 747, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (149, 578, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (150, 417, 'Alto', 'Aprobado', 'Evaluación de riesgo: Alto.'),
# (151, 874, 'Bajo', 'Rechazado', 'Evaluación de riesgo: Bajo.'),
# (152, 766, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (153, 472, 'Alto', 'Aprobado', 'Evaluación de riesgo: Alto.'),
# (154, 685, 'Medio', 'Rechazado', 'Evaluación de riesgo: Medio.'),
# (155, 714, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (156, 808, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (157, 494, 'Alto', 'Aprobado', 'Evaluación de riesgo: Alto.'),
# (158, 864, 'Bajo', 'Rechazado', 'Evaluación de riesgo: Bajo.'),
# (159, 647, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (160, 637, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (161, 670, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (162, 829, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (163, 884, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (164, 679, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (165, 835, 'Bajo', 'Pendiente', 'Evaluación de riesgo: Bajo.'),
# (166, 691, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (167, 841, 'Bajo', 'Pendiente', 'Evaluación de riesgo: Bajo.'),
# (168, 610, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (169, 782, 'Bajo', 'Pendiente', 'Evaluación de riesgo: Bajo.'),
# (170, 564, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (171, 504, 'Medio', 'Pendiente', 'Evaluación de riesgo: Medio.'),
# (172, 812, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (173, 390, 'Alto', 'Aprobado', 'Evaluación de riesgo: Alto.'),
# (174, 889, 'Bajo', 'Rechazado', 'Evaluación de riesgo: Bajo.'),
# (175, 512, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (176, 899, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (177, 632, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (178, 844, 'Bajo', 'Pendiente', 'Evaluación de riesgo: Bajo.'),
# (179, 441, 'Alto', 'Aprobado', 'Evaluación de riesgo: Alto.'),
# (180, 491, 'Alto', 'Rechazado', 'Evaluación de riesgo: Alto.'),
# (181, 632, 'Medio', 'Rechazado', 'Evaluación de riesgo: Medio.'),
# (182, 806, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (183, 861, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (184, 884, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (185, 766, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (186, 423, 'Alto', 'Aprobado', 'Evaluación de riesgo: Alto.'),
# (187, 573, 'Medio', 'Rechazado', 'Evaluación de riesgo: Medio.'),
# (188, 860, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (189, 886, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (190, 390, 'Alto', 'Aprobado', 'Evaluación de riesgo: Alto.'),
# (191, 723, 'Medio', 'Rechazado', 'Evaluación de riesgo: Medio.'),
# (192, 527, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (193, 547, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (194, 658, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (195, 642, 'Medio', 'Pendiente', 'Evaluación de riesgo: Medio.'),
# (196, 772, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (197, 885, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (198, 494, 'Alto', 'Aprobado', 'Evaluación de riesgo: Alto.'),
# (199, 879, 'Bajo', 'Rechazado', 'Evaluación de riesgo: Bajo.'),
# (200, 579, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
#
# Tabla 4: Pagos
# (8, 1723.14, 'Efectivo'),
# (8, 682.24, 'Transferencia'),
# (8, 691.7, 'Efectivo'),
# (8, 801.72, 'Transferencia'),
# (8, 256.43, 'Efectivo'),
# (8, 1756.54, 'Tarjeta'),
# (8, 295.46, 'Tarjeta'),
# (8, 1673.47, 'Transferencia'),
# (9, 1761.01, 'Transferencia'),
# (9, 1244.78, 'Transferencia'),
# (9, 1337.41, 'Tarjeta'),
# (9, 303.73, 'Transferencia'),
# (9, 1251.63, 'Efectivo'),
# (9, 1177.35, 'Efectivo'),
# (9, 1867.32, 'Efectivo'),
# (10, 872.77, 'Transferencia'),
# (10, 1836.06, 'Tarjeta'),
# (10, 820.19, 'Efectivo'),
# (10, 1512.4, 'Efectivo'),
# (10, 432.31, 'Efectivo'),
# (10, 350.67, 'Efectivo'),
# (10, 755.93, 'Efectivo'),
# (10, 1235.5, 'Efectivo'),
# (10, 355.64, 'Tarjeta'),
# (10, 1596.0, 'Efectivo'),
# (10, 1875.42, 'Efectivo'),
# (10, 1531.98, 'Tarjeta'),
# (11, 1401.34, 'Tarjeta'),
# (11, 724.78, 'Efectivo'),
# (11, 1134.54, 'Transferencia'),
# (11, 507.03, 'Transferencia'),
# (11, 772.39, 'Efectivo'),
# (11, 667.01, 'Efectivo'),
# (11, 1888.58, 'Tarjeta'),
# (12, 231.72, 'Tarjeta'),
# (12, 1132.81, 'Efectivo'),
# (12, 1746.12, 'Efectivo'),
# (13, 1540.54, 'Tarjeta'),
# (13, 1181.81, 'Efectivo'),
# (13, 1077.08, 'Transferencia'),
# (13, 171.91, 'Tarjeta'),
# (13, 986.88, 'Transferencia'),
# (13, 1013.01, 'Tarjeta'),
# (13, 1730.44, 'Tarjeta'),
# (13, 1767.35, 'Tarjeta'),
# (13, 1034.21, 'Transferencia'),
# (13, 318.6, 'Transferencia'),
# (13, 771.97, 'Transferencia'),
# (15, 1695.77, 'Tarjeta'),
# (15, 1363.99, 'Efectivo'),
# (15, 1976.47, 'Transferencia'),
# (15, 862.11, 'Transferencia'),
# (15, 641.55, 'Transferencia'),
# (15, 715.31, 'Transferencia'),
# (15, 1765.14, 'Transferencia'),
# (15, 1553.0, 'Tarjeta'),
# (15, 1427.56, 'Tarjeta'),
# (15, 1149.14, 'Efectivo'),
# (15, 647.13, 'Transferencia'),
# (17, 157.51, 'Efectivo'),
# (17, 1243.99, 'Transferencia'),
# (17, 463.15, 'Efectivo'),
# (17, 184.54, 'Transferencia'),
# (17, 713.03, 'Tarjeta'),
# (17, 889.3, 'Efectivo'),
# (17, 1612.77, 'Transferencia'),
# (17, 624.24, 'Transferencia'),
# (18, 962.93, 'Efectivo'),
# (18, 1900.8, 'Transferencia'),
# (18, 596.02, 'Efectivo'),
# (18, 148.36, 'Tarjeta'),
# (21, 128.25, 'Tarjeta'),
# (21, 1220.44, 'Tarjeta'),
# (21, 368.53, 'Transferencia'),
# (21, 193.91, 'Transferencia'),
# (21, 621.16, 'Transferencia'),
# (21, 357.43, 'Efectivo'),
# (21, 540.77, 'Tarjeta'),
# (21, 580.27, 'Efectivo'),
# (21, 231.11, 'Efectivo'),
# (21, 390.39, 'Transferencia'),
# (21, 1268.2, 'Transferencia'),
# (22, 1162.6, 'Transferencia'),
# (22, 1621.09, 'Tarjeta'),
# (22, 265.78, 'Tarjeta'),
# (22, 768.68, 'Efectivo'),
# (22, 1429.65, 'Transferencia'),
# (22, 1359.15, 'Transferencia'),
# (22, 1619.5, 'Efectivo'),
# (22, 1025.75, 'Transferencia'),
# (22, 1516.35, 'Transferencia'),
# (22, 1651.22, 'Transferencia'),
# (22, 586.77, 'Tarjeta'),
# (24, 1886.66, 'Transferencia'),
# (24, 772.65, 'Efectivo'),
# (24, 1512.41, 'Tarjeta'),
# (24, 491.25, 'Transferencia'),
# (24, 780.71, 'Transferencia'),
# (24, 1846.18, 'Tarjeta'),
# (24, 488.74, 'Transferencia'),
# (24, 446.86, 'Tarjeta'),
# (24, 783.87, 'Efectivo'),
# (24, 378.72, 'Efectivo'),
# (24, 342.93, 'Tarjeta'),
# (24, 888.16, 'Efectivo'),
# (25, 1645.95, 'Tarjeta'),
# (25, 1972.02, 'Transferencia'),
# (25, 1685.93, 'Efectivo'),
# (25, 1420.41, 'Efectivo'),
# (25, 464.66, 'Transferencia'),
# (25, 1493.29, 'Tarjeta'),
# (25, 849.99, 'Tarjeta'),
# (25, 677.15, 'Transferencia'),
# (25, 1549.45, 'Efectivo'),
# (30, 1151.04, 'Transferencia'),
# (30, 459.0, 'Efectivo'),
# (30, 1703.82, 'Transferencia'),
# (32, 738.14, 'Efectivo'),
# (32, 620.82, 'Efectivo'),
# (32, 357.16, 'Tarjeta'),
# (32, 1960.46, 'Transferencia'),
# (32, 814.28, 'Efectivo'),
# (32, 568.68, 'Efectivo'),
# (33, 495.42, 'Efectivo'),
# (33, 965.26, 'Tarjeta'),
# (33, 250.69, 'Efectivo'),
# (33, 410.47, 'Tarjeta'),
# (33, 896.25, 'Efectivo'),
# (37, 700.94, 'Efectivo'),
# (37, 1565.1, 'Transferencia'),
# (37, 1074.73, 'Transferencia'),
# (37, 636.35, 'Tarjeta'),
# (37, 1042.35, 'Tarjeta'),
# (37, 928.27, 'Efectivo'),
# (37, 1231.77, 'Transferencia'),
# (37, 1396.18, 'Transferencia'),
# (37, 301.89, 'Transferencia'),
# (37, 176.17, 'Transferencia'),
# (37, 1591.48, 'Efectivo'),
# (37, 1750.03, 'Transferencia'),
# (39, 264.39, 'Tarjeta'),
# (39, 1852.25, 'Tarjeta'),
# (39, 315.0, 'Tarjeta'),
# (39, 1528.58, 'Efectivo'),
# (39, 1398.0, 'Tarjeta'),
# (39, 1223.16, 'Efectivo'),
# (40, 987.32, 'Transferencia'),
# (40, 1404.03, 'Efectivo'),
# (41, 1510.72, 'Tarjeta'),
# (41, 1826.87, 'Transferencia'),
# (41, 1983.47, 'Efectivo'),
# (41, 780.69, 'Efectivo'),
# (41, 1996.46, 'Transferencia'),
# (41, 467.29, 'Transferencia'),
# (41, 966.4, 'Tarjeta'),
# (41, 584.5, 'Tarjeta'),
# (41, 282.48, 'Transferencia'),
# (41, 1147.54, 'Efectivo'),
# (41, 1217.17, 'Transferencia'),
# (41, 585.18, 'Transferencia'),
# (42, 1510.0, 'Transferencia'),
# (43, 1981.71, 'Tarjeta'),
# (43, 1449.03, 'Efectivo'),
# (43, 1817.88, 'Tarjeta'),
# (43, 1863.87, 'Tarjeta'),
# (43, 321.1, 'Efectivo'),
# (43, 161.14, 'Efectivo'),
# (43, 827.99, 'Efectivo'),
# (43, 501.2, 'Transferencia'),
# (43, 802.48, 'Tarjeta'),
# (46, 908.28, 'Transferencia'),
# (47, 1584.32, 'Tarjeta'),
# (47, 178.58, 'Transferencia'),
# (47, 424.48, 'Tarjeta'),
# (47, 884.64, 'Tarjeta'),
# (47, 1571.22, 'Transferencia'),
# (47, 1257.18, 'Transferencia'),
# (47, 163.14, 'Transferencia'),
# (47, 1199.47, 'Efectivo'),
# (47, 298.25, 'Efectivo'),
# (48, 1013.05, 'Transferencia'),
# (48, 685.27, 'Efectivo'),
# (48, 530.61, 'Tarjeta'),
# (49, 1306.03, 'Tarjeta'),
# (49, 410.09, 'Efectivo'),
# (49, 346.06, 'Tarjeta'),
# (49, 859.12, 'Transferencia'),
# (49, 1447.64, 'Tarjeta'),
# (49, 1494.01, 'Transferencia'),
# (49, 747.07, 'Efectivo'),
# (49, 272.9, 'Tarjeta'),
# (49, 1318.33, 'Tarjeta'),
# (49, 1660.24, 'Efectivo'),
# (49, 385.15, 'Transferencia'),
# (50, 458.07, 'Transferencia'),
# (50, 1139.45, 'Efectivo'),
# (50, 517.36, 'Tarjeta'),
# (50, 971.44, 'Tarjeta'),
# (50, 110.27, 'Transferencia'),
# (50, 712.39, 'Transferencia'),
# (50, 457.68, 'Efectivo'),
# (50, 778.99, 'Tarjeta'),
# (50, 1075.13, 'Tarjeta'),
# (50, 1613.62, 'Transferencia'),
# (50, 1225.81, 'Tarjeta'),
# (55, 704.36, 'Transferencia'),
# (55, 1605.51, 'Tarjeta'),
# (55, 1385.06, 'Tarjeta'),
# (55, 800.16, 'Transferencia'),
# (55, 588.46, 'Tarjeta'),
# (55, 1215.59, 'Tarjeta'),
# (55, 436.17, 'Tarjeta'),
# (55, 543.56, 'Efectivo'),
# (55, 1355.57, 'Tarjeta'),
# (55, 630.23, 'Efectivo'),
# (55, 568.62, 'Efectivo'),
# (55, 632.33, 'Efectivo'),
# (56, 614.38, 'Transferencia'),
# (56, 541.98, 'Tarjeta'),
# (56, 1100.26, 'Efectivo'),
# (56, 648.54, 'Tarjeta'),
# (57, 430.08, 'Tarjeta'),
# (57, 990.08, 'Tarjeta'),
# (57, 1825.97, 'Efectivo'),
# (57, 1309.13, 'Efectivo'),
# (57, 1562.24, 'Efectivo'),
# (57, 1351.28, 'Efectivo'),
# (57, 1584.47, 'Transferencia'),
# (57, 1498.44, 'Efectivo'),
# (57, 1264.27, 'Efectivo'),
# (57, 154.63, 'Transferencia'),
# (58, 1287.24, 'Tarjeta'),
# (58, 1554.93, 'Efectivo'),
# (58, 666.68, 'Transferencia'),
# (58, 1409.6, 'Transferencia'),
# (58, 225.15, 'Transferencia'),
# (58, 903.26, 'Efectivo'),
# (58, 744.46, 'Transferencia'),
# (58, 1004.89, 'Efectivo'),
# (58, 628.96, 'Tarjeta'),
# (58, 1373.69, 'Tarjeta'),
# (58, 1380.9, 'Efectivo'),
# (59, 110.56, 'Tarjeta'),
# (59, 1102.84, 'Tarjeta'),
# (59, 886.36, 'Efectivo'),
# (59, 1470.6, 'Efectivo'),
# (59, 779.34, 'Efectivo'),
# (59, 1617.65, 'Transferencia'),
# (59, 1692.56, 'Tarjeta'),
# (60, 1043.64, 'Efectivo'),
# (60, 1960.44, 'Transferencia'),
# (60, 915.72, 'Transferencia'),
# (60, 1823.59, 'Transferencia'),
# (60, 1599.81, 'Tarjeta'),
# (60, 1261.4, 'Efectivo'),
# (60, 372.51, 'Tarjeta'),
# (60, 1493.34, 'Transferencia'),
# (60, 1852.66, 'Efectivo'),
# (60, 765.7, 'Tarjeta'),
# (60, 1386.31, 'Transferencia'),
# (60, 569.12, 'Efectivo'),
# (61, 419.47, 'Tarjeta'),
# (61, 205.47, 'Tarjeta'),
# (61, 1816.29, 'Efectivo'),
# (61, 976.6, 'Transferencia'),
# (61, 1487.72, 'Tarjeta'),
# (61, 1368.4, 'Transferencia'),
# (61, 1603.23, 'Efectivo'),
# (61, 1694.81, 'Tarjeta'),
# (61, 674.28, 'Efectivo'),
# (63, 551.39, 'Efectivo'),
# (63, 1031.6, 'Efectivo'),
# (63, 1338.83, 'Transferencia'),
# (63, 1441.38, 'Efectivo'),
# (63, 1847.56, 'Tarjeta'),
# (63, 556.13, 'Efectivo'),
# (63, 398.49, 'Transferencia'),
# (63, 873.31, 'Efectivo'),
# (63, 434.52, 'Efectivo'),
# (63, 515.85, 'Efectivo'),
# (63, 494.43, 'Transferencia'),
# (63, 356.11, 'Efectivo'),
# (65, 1026.89, 'Tarjeta'),
# (65, 1069.94, 'Tarjeta'),
# (65, 276.54, 'Transferencia'),
# (65, 1615.53, 'Transferencia'),
# (65, 917.7, 'Efectivo'),
# (65, 1598.03, 'Efectivo'),
# (65, 890.71, 'Tarjeta'),
# (65, 516.79, 'Tarjeta'),
# (65, 895.13, 'Efectivo'),
# (65, 505.23, 'Efectivo'),
# (65, 1352.24, 'Tarjeta'),
# (65, 1788.06, 'Transferencia'),
# (68, 704.99, 'Tarjeta'),
# (68, 554.94, 'Transferencia'),
# (68, 1442.83, 'Tarjeta'),
# (68, 666.79, 'Transferencia'),
# (68, 1784.86, 'Transferencia'),
# (68, 1929.94, 'Transferencia'),
# (68, 1548.93, 'Efectivo'),
# (68, 1889.97, 'Efectivo'),
# (70, 1954.28, 'Efectivo'),
# (70, 1836.17, 'Efectivo'),
# (70, 799.16, 'Efectivo'),
# (70, 312.47, 'Tarjeta'),
# (70, 1459.86, 'Tarjeta'),
# (70, 1161.57, 'Tarjeta'),
# (70, 250.16, 'Tarjeta'),
# (70, 1506.01, 'Tarjeta'),
# (70, 904.33, 'Transferencia'),
# (70, 835.37, 'Tarjeta'),
# (70, 633.66, 'Tarjeta'),
# (70, 1262.11, 'Tarjeta'),
# (73, 1810.87, 'Efectivo'),
# (73, 1222.67, 'Transferencia'),
# (73, 911.34, 'Transferencia'),
# (73, 1805.24, 'Transferencia'),
# (73, 1939.7, 'Transferencia'),
# (73, 190.43, 'Efectivo'),
# (73, 719.31, 'Efectivo'),
# (73, 1391.16, 'Tarjeta'),
# (74, 922.07, 'Transferencia'),
# (74, 1116.35, 'Efectivo'),
# (74, 534.43, 'Tarjeta'),
# (74, 322.76, 'Tarjeta'),
# (74, 258.05, 'Tarjeta'),
# (74, 1555.94, 'Tarjeta'),
# (74, 1774.63, 'Tarjeta'),
# (74, 1211.43, 'Transferencia'),
# (74, 1412.21, 'Tarjeta'),
# (74, 1248.93, 'Efectivo'),
# (74, 1537.42, 'Efectivo'),
# (74, 1704.89, 'Transferencia'),
# (75, 704.59, 'Efectivo'),
# (75, 575.57, 'Transferencia'),
# (75, 1681.38, 'Tarjeta'),
# (75, 645.6, 'Tarjeta'),
# (75, 1005.85, 'Transferencia'),
# (75, 1511.84, 'Efectivo'),
# (75, 1608.35, 'Efectivo'),
# (75, 1121.29, 'Efectivo'),
# (75, 1214.74, 'Efectivo'),
# (75, 1741.02, 'Efectivo'),
# (75, 514.84, 'Efectivo'),
# (75, 1199.06, 'Tarjeta'),
# (76, 191.03, 'Transferencia'),
# (76, 275.03, 'Transferencia'),
# (76, 1316.45, 'Efectivo'),
# (76, 959.21, 'Efectivo'),
# (76, 690.63, 'Efectivo'),
# (76, 811.47, 'Transferencia'),
# (76, 122.21, 'Tarjeta'),
# (76, 1446.16, 'Efectivo'),
# (78, 231.16, 'Tarjeta'),
# (78, 140.06, 'Efectivo'),
# (78, 831.82, 'Transferencia'),
# (78, 1324.7, 'Efectivo'),
# (78, 861.55, 'Tarjeta'),
# (78, 1851.43, 'Transferencia'),
# (78, 832.96, 'Transferencia'),
# (78, 1530.42, 'Transferencia'),
# (78, 1701.69, 'Efectivo'),
# (79, 1871.04, 'Tarjeta'),
# (79, 1198.35, 'Efectivo'),
# (79, 1310.08, 'Tarjeta'),
# (79, 1035.82, 'Tarjeta'),
# (79, 1132.15, 'Tarjeta'),
# (79, 1719.09, 'Tarjeta'),
# (80, 787.62, 'Efectivo'),
# (80, 200.95, 'Transferencia'),
# (80, 1988.44, 'Tarjeta'),
# (80, 707.48, 'Transferencia'),
# (80, 1230.0, 'Efectivo'),
# (80, 1795.34, 'Transferencia'),
# (80, 1867.91, 'Efectivo'),
# (80, 318.09, 'Tarjeta'),
# (80, 1517.12, 'Efectivo'),
# (81, 907.15, 'Tarjeta'),
# (81, 929.59, 'Efectivo'),
# (81, 987.34, 'Tarjeta'),
# (82, 1119.5, 'Transferencia'),
# (82, 1998.39, 'Transferencia'),
# (82, 684.98, 'Transferencia'),
# (82, 261.9, 'Efectivo'),
# (82, 1416.29, 'Efectivo'),
# (82, 1051.82, 'Tarjeta'),
# (82, 859.63, 'Transferencia'),
# (82, 737.01, 'Efectivo'),
# (82, 576.56, 'Efectivo'),
# (82, 622.24, 'Transferencia'),
# (82, 1818.47, 'Transferencia'),
# (84, 961.03, 'Efectivo'),
# (84, 1081.31, 'Efectivo'),
# (84, 1701.28, 'Tarjeta'),
# (84, 550.65, 'Tarjeta'),
# (84, 1484.5, 'Efectivo'),
# (84, 484.66, 'Efectivo'),
# (86, 1192.98, 'Efectivo'),
# (86, 620.57, 'Efectivo'),
# (86, 1770.77, 'Tarjeta'),
# (86, 921.09, 'Tarjeta'),
# (86, 125.02, 'Efectivo'),
# (86, 1744.9, 'Tarjeta'),
# (86, 506.73, 'Transferencia'),
# (86, 1679.07, 'Efectivo'),
# (86, 1002.83, 'Transferencia'),
# (86, 676.1, 'Efectivo'),
# (88, 197.09, 'Tarjeta'),
# (88, 303.23, 'Efectivo'),
# (88, 921.88, 'Tarjeta'),
# (88, 729.78, 'Tarjeta'),
# (88, 951.74, 'Transferencia'),
# (88, 795.04, 'Tarjeta'),
# (88, 979.27, 'Efectivo'),
# (89, 293.67, 'Tarjeta'),
# (89, 1515.1, 'Transferencia'),
# (89, 299.88, 'Efectivo'),
# (89, 990.06, 'Transferencia'),
# (89, 635.63, 'Transferencia'),
# (89, 663.36, 'Tarjeta'),
# (89, 239.92, 'Efectivo'),
# (89, 1145.79, 'Transferencia'),
# (89, 1441.75, 'Efectivo'),
# (89, 317.46, 'Efectivo'),
# (90, 1915.87, 'Transferencia'),
# (90, 1322.87, 'Tarjeta'),
# (90, 1047.86, 'Transferencia'),
# (90, 1775.3, 'Efectivo'),
# (90, 614.28, 'Transferencia'),
# (90, 1008.7, 'Transferencia'),
# (90, 387.27, 'Efectivo'),
# (90, 866.76, 'Transferencia'),
# (90, 1090.59, 'Tarjeta'),
# (92, 1766.44, 'Efectivo'),
# (92, 878.73, 'Efectivo'),
# (92, 1030.6, 'Efectivo'),
# (92, 716.49, 'Tarjeta'),
# (92, 1821.13, 'Tarjeta'),
# (92, 773.22, 'Transferencia'),
# (92, 420.91, 'Transferencia'),
# (93, 225.15, 'Tarjeta'),
# (93, 1708.38, 'Transferencia'),
# (93, 790.4, 'Efectivo'),
# (93, 1517.96, 'Tarjeta'),
# (93, 338.03, 'Transferencia'),
# (93, 1490.49, 'Transferencia'),
# (93, 1410.69, 'Tarjeta'),
# (93, 307.63, 'Transferencia'),
# (93, 1040.15, 'Tarjeta'),
# (95, 912.59, 'Efectivo'),
# (95, 622.9, 'Efectivo'),
# (95, 477.18, 'Tarjeta'),
# (96, 562.48, 'Tarjeta'),
# (96, 1749.9, 'Tarjeta'),
# (96, 280.4, 'Transferencia'),
# (96, 1969.73, 'Tarjeta'),
# (96, 1923.7, 'Efectivo'),
# (96, 636.41, 'Transferencia'),
# (96, 613.85, 'Tarjeta'),
# (96, 679.46, 'Efectivo'),
# (96, 1790.21, 'Transferencia'),
# (97, 1397.15, 'Transferencia'),
# (97, 601.19, 'Tarjeta'),
# (97, 1651.11, 'Efectivo'),
# (97, 290.82, 'Transferencia'),
# (97, 626.45, 'Transferencia'),
# (97, 1740.95, 'Transferencia'),
# (97, 1372.41, 'Transferencia'),
# (97, 1464.61, 'Transferencia'),
# (97, 1733.05, 'Efectivo'),
# (97, 1438.14, 'Tarjeta'),
# (97, 184.56, 'Tarjeta'),
# (97, 1823.92, 'Efectivo'),
# (99, 1690.52, 'Efectivo'),
# (99, 528.22, 'Efectivo'),
# (99, 1834.32, 'Tarjeta'),
# (99, 1541.64, 'Tarjeta'),
# (99, 832.98, 'Tarjeta'),
# (99, 1484.34, 'Transferencia'),
# (99, 993.99, 'Efectivo'),
# (99, 1688.45, 'Transferencia'),
# (99, 1035.45, 'Transferencia'),
# (99, 900.11, 'Efectivo'),
# (100, 1966.43, 'Tarjeta'),
# (100, 1856.61, 'Tarjeta'),
# (100, 175.42, 'Efectivo'),
# (100, 659.43, 'Tarjeta'),
# (100, 1592.39, 'Transferencia'),
# (100, 1663.11, 'Tarjeta'),
# (100, 1354.99, 'Tarjeta'),
# (100, 668.24, 'Tarjeta'),
# (100, 1389.8, 'Tarjeta'),
# (100, 1531.97, 'Efectivo'),
# (100, 1545.0, 'Efectivo'),
# (105, 910.31, 'Tarjeta'),
# (105, 1061.91, 'Efectivo'),
# (105, 1750.37, 'Tarjeta'),
# (105, 1707.52, 'Transferencia'),
# (105, 783.34, 'Tarjeta'),
# (105, 241.3, 'Tarjeta'),
# (105, 1102.99, 'Transferencia'),
# (105, 520.29, 'Transferencia'),
# (105, 1047.6, 'Transferencia'),
# (106, 1341.77, 'Efectivo'),
# (106, 1394.86, 'Tarjeta'),
# (106, 757.75, 'Efectivo'),
# (106, 1536.9, 'Tarjeta'),
# (106, 1241.8, 'Transferencia'),
# (106, 461.07, 'Tarjeta'),
# (110, 1450.93, 'Tarjeta'),
# (110, 616.64, 'Efectivo'),
# (110, 1235.25, 'Transferencia'),
# (110, 1655.02, 'Efectivo'),
# (110, 674.83, 'Efectivo'),
# (110, 1478.83, 'Efectivo'),
# (110, 1617.61, 'Transferencia'),
# (110, 784.46, 'Transferencia'),
# (110, 104.08, 'Efectivo'),
# (110, 242.66, 'Efectivo'),
# (110, 1540.93, 'Transferencia'),
# (110, 708.5, 'Tarjeta'),
# (113, 1862.04, 'Efectivo'),
# (113, 1456.3, 'Tarjeta'),
# (113, 861.78, 'Efectivo'),
# (113, 1848.19, 'Tarjeta'),
# (113, 1507.72, 'Efectivo'),
# (113, 221.76, 'Efectivo'),
# (113, 1134.67, 'Efectivo'),
# (113, 1538.13, 'Efectivo'),
# (113, 1543.21, 'Tarjeta'),
# (113, 992.67, 'Transferencia'),
# (114, 301.63, 'Transferencia'),
# (114, 1602.57, 'Tarjeta'),
# (114, 1533.8, 'Tarjeta'),
# (114, 1819.05, 'Efectivo'),
# (114, 1800.11, 'Tarjeta'),
# (114, 285.49, 'Transferencia'),
# (114, 360.58, 'Tarjeta'),
# (114, 1110.05, 'Efectivo'),
# (115, 1286.9, 'Tarjeta'),
# (115, 626.59, 'Transferencia'),
# (115, 1588.88, 'Efectivo'),
# (115, 175.53, 'Tarjeta'),
# (115, 611.56, 'Efectivo'),
# (117, 128.07, 'Tarjeta'),
# (117, 1798.47, 'Efectivo'),
# (117, 1330.92, 'Tarjeta'),
# (117, 212.71, 'Efectivo'),
# (117, 1714.96, 'Efectivo'),
# (119, 1360.84, 'Tarjeta'),
# (119, 1425.28, 'Efectivo'),
# (119, 1382.04, 'Transferencia'),
# (119, 136.52, 'Efectivo'),
# (119, 1609.67, 'Transferencia'),
# (120, 1085.65, 'Tarjeta'),
# (120, 437.2, 'Transferencia'),
# (120, 252.75, 'Transferencia'),
# (120, 1325.93, 'Tarjeta'),
# (120, 1418.52, 'Efectivo'),
# (120, 758.4, 'Tarjeta'),
# (120, 1740.13, 'Tarjeta'),
# (120, 1864.95, 'Efectivo'),
# (120, 694.26, 'Tarjeta'),
# (120, 1558.61, 'Transferencia'),
# (120, 1103.86, 'Transferencia'),
# (120, 648.04, 'Transferencia'),
# (121, 218.96, 'Transferencia'),
# (121, 924.14, 'Tarjeta'),
# (121, 1996.39, 'Efectivo'),
# (121, 479.99, 'Tarjeta'),
# (121, 1489.41, 'Tarjeta'),
# (121, 1337.25, 'Transferencia'),
# (121, 128.88, 'Efectivo'),
# (121, 1853.57, 'Efectivo'),
# (121, 215.52, 'Efectivo'),
# (121, 1031.39, 'Efectivo'),
# (121, 1732.49, 'Tarjeta'),
# (121, 254.02, 'Efectivo'),
# (122, 677.33, 'Transferencia'),
# (122, 900.7, 'Tarjeta'),
# (122, 1812.13, 'Tarjeta'),
# (122, 447.57, 'Efectivo'),
# (122, 1673.19, 'Transferencia'),
# (122, 118.92, 'Efectivo'),
# (122, 423.34, 'Tarjeta'),
# (122, 823.78, 'Efectivo'),
# (122, 1595.66, 'Efectivo'),
# (123, 1688.24, 'Efectivo'),
# (123, 1608.3, 'Efectivo'),
# (123, 1622.69, 'Tarjeta'),
# (125, 950.74, 'Efectivo'),
# (125, 1281.97, 'Transferencia'),
# (125, 1281.78, 'Efectivo'),
# (125, 1402.54, 'Tarjeta'),
# (125, 633.02, 'Efectivo'),
# (125, 616.07, 'Transferencia'),
# (125, 1357.43, 'Efectivo'),
# (130, 1199.56, 'Tarjeta'),
# (132, 658.59, 'Transferencia'),
# (132, 1229.22, 'Transferencia'),
# (132, 138.34, 'Transferencia'),
# (132, 990.45, 'Efectivo'),
# (132, 103.32, 'Efectivo'),
# (132, 455.47, 'Tarjeta'),
# (132, 780.21, 'Efectivo'),
# (133, 1261.01, 'Transferencia'),
# (134, 485.07, 'Transferencia'),
# (134, 1661.82, 'Efectivo'),
# (134, 1716.9, 'Efectivo'),
# (134, 325.04, 'Transferencia'),
# (139, 1640.47, 'Tarjeta'),
# (139, 235.93, 'Transferencia'),
# (139, 975.0, 'Transferencia'),
# (139, 1015.92, 'Efectivo'),
# (139, 277.65, 'Tarjeta'),
# (139, 567.14, 'Transferencia'),
# (139, 1175.32, 'Tarjeta'),
# (139, 917.07, 'Transferencia'),
# (139, 720.43, 'Efectivo'),
# (139, 653.86, 'Tarjeta'),
# (139, 213.6, 'Tarjeta'),
# (139, 739.51, 'Transferencia'),
# (140, 1347.95, 'Transferencia'),
# (140, 1681.37, 'Transferencia'),
# (141, 1696.73, 'Efectivo'),
# (141, 1744.21, 'Efectivo'),
# (141, 868.71, 'Tarjeta'),
# (141, 1278.98, 'Transferencia'),
# (141, 1369.78, 'Efectivo'),
# (141, 1364.06, 'Efectivo'),
# (141, 1949.16, 'Efectivo'),
# (141, 127.43, 'Transferencia'),
# (141, 1448.05, 'Tarjeta'),
# (141, 757.32, 'Transferencia'),
# (142, 782.07, 'Transferencia'),
# (142, 1575.92, 'Efectivo'),
# (142, 370.2, 'Efectivo'),
# (142, 367.72, 'Efectivo'),
# (142, 1460.49, 'Transferencia'),
# (142, 1343.24, 'Efectivo'),
# (142, 950.64, 'Tarjeta'),
# (142, 326.73, 'Transferencia'),
# (142, 1145.98, 'Tarjeta'),
# (142, 585.15, 'Tarjeta'),
# (142, 1234.52, 'Tarjeta'),
# (142, 602.88, 'Tarjeta'),
# (143, 1879.84, 'Tarjeta'),
# (143, 935.24, 'Tarjeta'),
# (143, 1826.8, 'Efectivo'),
# (143, 1752.85, 'Tarjeta'),
# (143, 1592.64, 'Tarjeta'),
# (143, 1743.72, 'Transferencia'),
# (143, 727.98, 'Transferencia'),
# (143, 657.18, 'Tarjeta'),
# (143, 1068.0, 'Transferencia'),
# (144, 1187.39, 'Efectivo'),
# (144, 854.51, 'Efectivo'),
# (144, 970.0, 'Efectivo'),
# (144, 156.56, 'Transferencia'),
# (144, 194.35, 'Efectivo'),
# (144, 1173.61, 'Efectivo'),
# (145, 1807.78, 'Tarjeta'),
# (145, 1077.46, 'Tarjeta'),
# (145, 1573.17, 'Transferencia'),
# (145, 264.71, 'Tarjeta'),
# (145, 592.33, 'Transferencia'),
# (145, 234.87, 'Efectivo'),
# (145, 1452.98, 'Transferencia'),
# (145, 1693.23, 'Efectivo'),
# (145, 1055.57, 'Transferencia'),
# (146, 463.12, 'Efectivo'),
# (146, 1354.83, 'Tarjeta'),
# (146, 1591.98, 'Efectivo'),
# (146, 1161.54, 'Efectivo'),
# (147, 1814.44, 'Tarjeta'),
# (147, 1211.87, 'Efectivo'),
# (147, 1468.51, 'Transferencia'),
# (147, 218.77, 'Transferencia'),
# (147, 647.35, 'Efectivo'),
# (147, 469.63, 'Efectivo'),
# (148, 1133.59, 'Transferencia'),
# (148, 1886.01, 'Transferencia'),
# (148, 335.98, 'Transferencia'),
# (148, 358.82, 'Efectivo'),
# (148, 1432.17, 'Tarjeta'),
# (148, 1550.24, 'Efectivo'),
# (148, 670.86, 'Tarjeta'),
# (148, 1137.14, 'Transferencia'),
# (148, 1776.66, 'Efectivo'),
# (148, 1465.64, 'Efectivo'),
# (148, 996.7, 'Tarjeta'),
# (148, 535.14, 'Transferencia'),
# (149, 1385.04, 'Transferencia'),
# (149, 1876.08, 'Efectivo'),
# (149, 1304.24, 'Transferencia'),
# (149, 1349.96, 'Transferencia'),
# (149, 228.18, 'Tarjeta'),
# (149, 786.88, 'Transferencia'),
# (149, 896.69, 'Transferencia'),
# (149, 911.06, 'Tarjeta'),
# (149, 1512.86, 'Efectivo'),
# (149, 1424.16, 'Tarjeta'),
# (149, 1105.23, 'Efectivo'),
# (151, 723.11, 'Efectivo'),
# (151, 305.63, 'Efectivo'),
# (151, 451.3, 'Tarjeta'),
# (152, 1882.11, 'Efectivo'),
# (152, 888.62, 'Tarjeta'),
# (152, 554.77, 'Tarjeta'),
# (152, 1606.05, 'Efectivo'),
# (152, 761.6, 'Transferencia'),
# (152, 544.97, 'Efectivo'),
# (152, 1147.77, 'Tarjeta'),
# (152, 416.51, 'Efectivo'),
# (152, 1467.44, 'Tarjeta'),
# (152, 483.96, 'Transferencia'),
# (152, 1773.88, 'Efectivo'),
# (152, 1515.78, 'Transferencia'),
# (154, 1950.63, 'Efectivo'),
# (154, 724.99, 'Tarjeta'),
# (154, 739.47, 'Efectivo'),
# (154, 1679.64, 'Tarjeta'),
# (154, 1788.02, 'Tarjeta'),
# (154, 1606.7, 'Tarjeta'),
# (154, 748.44, 'Efectivo'),
# (154, 1174.71, 'Transferencia'),
# (154, 950.35, 'Transferencia'),
# (155, 1401.03, 'Transferencia'),
# (155, 1750.55, 'Transferencia'),
# (155, 1941.38, 'Tarjeta'),
# (155, 1539.08, 'Efectivo'),
# (155, 1587.27, 'Tarjeta'),
# (155, 1285.07, 'Efectivo'),
# (156, 279.95, 'Tarjeta'),
# (156, 1920.26, 'Tarjeta'),
# (156, 1441.72, 'Efectivo'),
# (158, 681.64, 'Transferencia'),
# (158, 179.43, 'Transferencia'),
# (158, 1930.86, 'Transferencia'),
# (158, 1274.71, 'Transferencia'),
# (158, 730.72, 'Efectivo'),
# (158, 472.23, 'Transferencia'),
# (158, 868.45, 'Tarjeta'),
# (158, 468.26, 'Transferencia'),
# (158, 748.76, 'Transferencia'),
# (159, 629.72, 'Transferencia'),
# (159, 1763.07, 'Efectivo'),
# (159, 179.17, 'Efectivo'),
# (160, 852.27, 'Efectivo'),
# (160, 1887.45, 'Tarjeta'),
# (160, 230.36, 'Efectivo'),
# (160, 1546.41, 'Efectivo'),
# (160, 1835.73, 'Tarjeta'),
# (161, 1210.53, 'Tarjeta'),
# (161, 1175.82, 'Transferencia'),
# (161, 338.42, 'Efectivo'),
# (161, 995.37, 'Tarjeta'),
# (161, 208.62, 'Tarjeta'),
# (161, 656.78, 'Efectivo'),
# (161, 147.29, 'Efectivo'),
# (162, 209.07, 'Tarjeta'),
# (162, 1910.36, 'Transferencia'),
# (162, 1863.32, 'Tarjeta'),
# (162, 907.61, 'Tarjeta'),
# (163, 1738.72, 'Tarjeta'),
# (163, 1739.92, 'Tarjeta'),
# (163, 1544.73, 'Efectivo'),
# (163, 1036.8, 'Transferencia'),
# (163, 945.15, 'Transferencia'),
# (163, 386.49, 'Transferencia'),
# (163, 339.21, 'Transferencia'),
# (165, 1648.95, 'Tarjeta'),
# (165, 130.46, 'Transferencia'),
# (165, 818.75, 'Tarjeta'),
# (165, 1116.81, 'Tarjeta'),
# (167, 1776.97, 'Transferencia'),
# (167, 178.55, 'Efectivo'),
# (167, 1487.83, 'Efectivo'),
# (167, 274.68, 'Tarjeta'),
# (167, 1747.07, 'Efectivo'),
# (167, 1970.3, 'Efectivo'),
# (167, 592.22, 'Transferencia'),
# (167, 1983.67, 'Tarjeta'),
# (167, 1484.1, 'Transferencia'),
# (167, 497.68, 'Efectivo'),
# (169, 820.38, 'Tarjeta'),
# (169, 1497.6, 'Tarjeta'),
# (169, 1727.87, 'Efectivo'),
# (169, 1154.75, 'Efectivo'),
# (169, 584.59, 'Efectivo'),
# (169, 125.45, 'Tarjeta'),
# (169, 307.53, 'Efectivo'),
# (169, 201.78, 'Efectivo'),
# (169, 1811.94, 'Transferencia'),
# (169, 1083.74, 'Tarjeta'),
# (169, 500.17, 'Transferencia'),
# (169, 1981.03, 'Tarjeta'),
# (171, 1015.26, 'Efectivo'),
# (171, 1981.31, 'Tarjeta'),
# (171, 1151.75, 'Tarjeta'),
# (171, 981.84, 'Tarjeta'),
# (171, 1297.18, 'Tarjeta'),
# (171, 156.89, 'Transferencia'),
# (171, 1977.38, 'Tarjeta'),
# (171, 514.36, 'Tarjeta'),
# (171, 1610.51, 'Efectivo'),
# (171, 1157.76, 'Efectivo'),
# (171, 1148.48, 'Efectivo'),
# (172, 284.39, 'Tarjeta'),
# (172, 281.41, 'Efectivo'),
# (172, 1059.98, 'Transferencia'),
# (172, 1408.01, 'Transferencia'),
# (172, 1231.28, 'Transferencia'),
# (172, 1015.5, 'Tarjeta'),
# (172, 288.52, 'Tarjeta'),
# (172, 1003.65, 'Tarjeta'),
# (172, 330.5, 'Transferencia'),
# (172, 685.02, 'Tarjeta'),
# (172, 1723.25, 'Efectivo'),
# (172, 1076.79, 'Tarjeta'),
# (174, 1798.24, 'Tarjeta'),
# (174, 129.08, 'Efectivo'),
# (174, 1817.77, 'Efectivo'),
# (174, 1941.67, 'Tarjeta'),
# (174, 1118.94, 'Efectivo'),
# (175, 1762.87, 'Efectivo'),
# (176, 858.89, 'Efectivo'),
# (176, 1917.94, 'Transferencia'),
# (176, 1722.18, 'Transferencia'),
# (178, 793.35, 'Transferencia'),
# (178, 213.64, 'Transferencia'),
# (178, 791.59, 'Transferencia'),
# (178, 1152.13, 'Tarjeta'),
# (178, 434.33, 'Tarjeta'),
# (178, 1296.54, 'Tarjeta'),
# (178, 281.93, 'Efectivo'),
# (178, 173.87, 'Transferencia'),
# (178, 409.25, 'Efectivo'),
# (178, 334.92, 'Efectivo'),
# (178, 212.2, 'Transferencia'),
# (178, 439.32, 'Efectivo'),
# (181, 1915.71, 'Transferencia'),
# (181, 1937.78, 'Transferencia'),
# (181, 535.65, 'Efectivo'),
# (181, 1488.24, 'Tarjeta'),
# (181, 1952.28, 'Transferencia'),
# (181, 1664.55, 'Transferencia'),
# (181, 380.62, 'Transferencia'),
# (181, 1890.41, 'Tarjeta'),
# (181, 666.25, 'Efectivo'),
# (181, 813.36, 'Efectivo'),
# (181, 1819.2, 'Efectivo'),
# (181, 172.63, 'Efectivo'),
# (182, 663.31, 'Efectivo'),
# (183, 831.31, 'Tarjeta'),
# (183, 768.3, 'Tarjeta'),
# (183, 1494.01, 'Transferencia'),
# (183, 227.39, 'Tarjeta'),
# (183, 679.4, 'Tarjeta'),
# (183, 466.1, 'Tarjeta'),
# (183, 1305.41, 'Tarjeta'),
# (184, 1979.59, 'Transferencia'),
# (184, 102.94, 'Tarjeta'),
# (184, 889.54, 'Transferencia'),
# (184, 184.93, 'Transferencia'),
# (184, 1725.7, 'Efectivo'),
# (184, 1341.72, 'Efectivo'),
# (184, 1933.94, 'Tarjeta'),
# (185, 977.88, 'Efectivo'),
# (185, 1962.74, 'Efectivo'),
# (185, 1796.78, 'Tarjeta'),
# (185, 1387.85, 'Tarjeta'),
# (185, 981.27, 'Tarjeta'),
# (185, 1752.73, 'Tarjeta'),
# (185, 875.48, 'Efectivo'),
# (185, 844.27, 'Transferencia'),
# (187, 1880.34, 'Efectivo'),
# (187, 283.8, 'Transferencia'),
# (187, 828.03, 'Transferencia'),
# (187, 871.52, 'Tarjeta'),
# (188, 644.24, 'Transferencia'),
# (188, 1371.63, 'Efectivo'),
# (189, 977.3, 'Transferencia'),
# (189, 1383.18, 'Tarjeta'),
# (189, 1398.79, 'Tarjeta'),
# (189, 126.54, 'Transferencia'),
# (189, 1336.54, 'Efectivo'),
# (189, 480.04, 'Tarjeta'),
# (189, 1947.21, 'Efectivo'),
# (189, 1160.01, 'Transferencia'),
# (189, 1628.06, 'Transferencia'),
# (189, 1784.94, 'Transferencia'),
# (191, 892.1, 'Tarjeta'),
# (191, 1329.5, 'Efectivo'),
# (191, 1155.28, 'Transferencia'),
# (191, 1644.59, 'Efectivo'),
# (191, 151.27, 'Transferencia'),
# (191, 543.12, 'Tarjeta'),
# (191, 893.07, 'Transferencia'),
# (191, 1949.25, 'Efectivo'),
# (191, 162.87, 'Transferencia'),
# (192, 129.44, 'Tarjeta'),
# (192, 1780.61, 'Tarjeta'),
# (193, 1684.59, 'Tarjeta'),
# (193, 700.79, 'Efectivo'),
# (193, 917.71, 'Efectivo'),
# (193, 1453.52, 'Transferencia'),
# (193, 1685.76, 'Tarjeta'),
# (193, 1771.13, 'Transferencia'),
# (193, 1750.35, 'Efectivo'),
# (195, 679.18, 'Transferencia'),
# (195, 717.94, 'Transferencia'),
# (195, 1307.77, 'Tarjeta'),
# (195, 209.2, 'Tarjeta'),
# (195, 794.21, 'Tarjeta'),
# (195, 524.76, 'Transferencia'),
# (195, 546.56, 'Tarjeta'),
# (195, 200.73, 'Transferencia'),
# (195, 1808.81, 'Tarjeta'),
# (195, 688.01, 'Efectivo'),
# (195, 470.95, 'Tarjeta'),
# (195, 855.62, 'Transferencia'),
# (196, 991.68, 'Tarjeta'),
# (197, 1016.01, 'Tarjeta'),
# (197, 1742.42, 'Transferencia'),
# (197, 1676.41, 'Efectivo'),
# (197, 615.59, 'Transferencia'),
# (197, 296.41, 'Tarjeta'),
# (197, 296.78, 'Transferencia'),
# (197, 1882.68, 'Efectivo'),
# (199, 633.99, 'Transferencia'),
# (199, 924.4, 'Efectivo'),
# (199, 1669.42, 'Tarjeta'),
# (199, 1062.73, 'Transferencia'),
# (199, 905.01, 'Transferencia'),
# (199, 1274.67, 'Transferencia'),
# (200, 651.38, 'Efectivo'),
# (200, 203.93, 'Tarjeta'),
# (200, 1980.22, 'Efectivo'),
# (200, 1207.21, 'Tarjeta'),
# (200, 1931.56, 'Tarjeta'),
# (200, 576.74, 'Efectivo'),
# (200, 571.0, 'Efectivo'),
# (200, 224.43, 'Efectivo'),
# (200, 1305.05, 'Tarjeta'),
# (200, 455.06, 'Efectivo'),
#
# Tabla 5: Historial crediticio
# (1, 50317.84, 2, 'Bueno'),
# (2, 63359.25, 5, 'Bueno'),
# (3, 69521.27, 4, 'Malo'),
# (4, 34299.47, 1, 'Bueno'),
# (5, 10089.6, 1, 'Bueno'),
# (6, 0, 0, 'Bueno'),
# (7, 16226.9, 2, 'Bueno'),
# (8, 17464.98, 5, 'Bueno'),
# (9, 0, 0, 'Bueno'),
# (10, 0, 0, 'Bueno'),
# (11, 53905.22, 2, 'Regular'),
# (12, 0, 0, 'Bueno'),
# (13, 54338.69, 1, 'Bueno'),
# (14, 77523.47, 3, 'Bueno'),
# (15, 84319.7, 3, 'Regular'),
# (16, 35755.0, 1, 'Malo'),
# (17, 53383.34, 1, 'Bueno'),
# (18, 58805.47, 2, 'Bueno'),
# (19, 14097.46, 1, 'Malo'),
# (20, 0, 0, 'Bueno'),
# (21, 41007.45, 5, 'Regular'),
# (22, 46535.84, 3, 'Regular'),
# (23, 70289.54, 3, 'Regular'),
# (24, 73293.39, 5, 'Bueno'),
# (25, 24854.75, 3, 'Bueno'),
# (26, 97352.63, 2, 'Bueno'),
# (27, 85285.06, 2, 'Regular'),
# (28, 70830.77, 3, 'Regular'),
# (29, 27671.12, 3, 'Bueno'),
# (30, 20473.79, 1, 'Malo'),
# (31, 0, 0, 'Bueno'),
# (32, 0, 0, 'Bueno'),
# (33, 24453.2, 3, 'Bueno'),
# (34, 38854.0, 2, 'Regular'),
# (35, 0, 0, 'Bueno'),
# (36, 77549.19, 3, 'Bueno'),
# (37, 45168.04, 2, 'Bueno'),
# (38, 49255.69, 2, 'Bueno'),
# (39, 59648.55, 4, 'Bueno'),
# (40, 87857.85, 4, 'Malo'),
# (41, 26434.83, 3, 'Bueno'),
# (42, 48903.58, 1, 'Regular'),
# (43, 55755.26, 3, 'Bueno'),
# (44, 73145.1, 4, 'Bueno'),
# (45, 53160.28, 4, 'Bueno'),
# (46, 51148.56, 1, 'Regular'),
# (47, 0, 0, 'Bueno'),
# (48, 34776.47, 4, 'Bueno'),
# (49, 57555.58, 4, 'Regular'),
# (50, 86050.72, 2, 'Regular'),
# (51, 11718.24, 1, 'Malo'),
# (52, 17462.01, 4, 'Bueno'),
# (53, 0, 0, 'Bueno'),
# (54, 98673.24, 4, 'Bueno'),
# (55, 80549.79, 3, 'Bueno'),
# (56, 23112.23, 5, 'Malo'),
# (57, 0, 0, 'Bueno'),
# (58, 0, 0, 'Bueno'),
# (59, 54011.12, 4, 'Regular'),
# (60, 89608.06, 3, 'Bueno'),
# (61, 0, 0, 'Bueno'),
# (62, 14631.02, 3, 'Bueno'),
# (63, 37349.75, 2, 'Regular'),
# (64, 13839.84, 2, 'Bueno'),
# (65, 30316.74, 3, 'Bueno'),
# (66, 3865.46, 4, 'Regular'),
# (67, 58948.23, 3, 'Bueno'),
# (68, 63831.71, 2, 'Regular'),
# (69, 23278.18, 2, 'Regular'),
# (70, 43427.76, 4, 'Malo'),
# (71, 76988.69, 2, 'Bueno'),
# (72, 22582.15, 1, 'Bueno'),
# (73, 74986.08, 3, 'Regular'),
# (74, 0, 0, 'Bueno'),
# (75, 0, 0, 'Bueno'),
# (76, 0, 0, 'Bueno'),
# (77, 27423.05, 4, 'Regular'),
# (78, 41645.36, 3, 'Bueno'),
# (79, 83737.22, 1, 'Bueno'),
# (80, 24273.94, 2, 'Bueno'),
# (81, 0, 0, 'Bueno'),
# (82, 41797.14, 2, 'Bueno'),
# (83, 83393.22, 3, 'Bueno'),
# (84, 0, 0, 'Bueno'),
# (85, 15811.77, 2, 'Regular'),
# (86, 13395.05, 2, 'Bueno'),
# (87, 96343.52, 5, 'Regular'),
# (88, 13071.57, 5, 'Malo'),
# (89, 88419.77, 4, 'Bueno'),
# (90, 90699.58, 2, 'Bueno'),
# (91, 0, 0, 'Bueno'),
# (92, 98452.51, 1, 'Bueno'),
# (93, 87715.25, 5, 'Bueno'),
# (94, 0, 0, 'Bueno'),
# (95, 65859.15, 5, 'Regular'),
# (96, 67263.69, 3, 'Regular'),
# (97, 0, 0, 'Bueno'),
# (98, 47541.34, 4, 'Bueno'),
# (99, 42568.81, 2, 'Bueno'),
# (100, 0, 0, 'Bueno'),
# (101, 16885.89, 2, 'Regular'),
# (102, 0, 0, 'Bueno'),
# (103, 89345.86, 4, 'Bueno'),
# (104, 66955.74, 5, 'Bueno'),
# (105, 58580.34, 5, 'Bueno'),
# (106, 2884.92, 2, 'Regular'),
# (107, 0, 0, 'Bueno'),
# (108, 93736.27, 4, 'Bueno'),
# (109, 0, 0, 'Bueno'),
# (110, 0, 0, 'Bueno'),
# (111, 0, 0, 'Bueno'),
# (112, 91966.33, 1, 'Bueno'),
# (113, 72512.86, 4, 'Bueno'),
# (114, 83392.24, 2, 'Bueno'),
# (115, 13740.52, 1, 'Regular'),
# (116, 14110.31, 3, 'Bueno'),
# (117, 66179.77, 3, 'Bueno'),
# (118, 86454.73, 1, 'Bueno'),
# (119, 39205.98, 3, 'Bueno'),
# (120, 22533.08, 1, 'Malo'),
# (121, 31346.79, 1, 'Regular'),
# (122, 26082.84, 5, 'Regular'),
# (123, 0, 0, 'Bueno'),
# (124, 47812.44, 1, 'Regular'),
# (125, 25166.85, 4, 'Bueno'),
# (126, 0, 0, 'Bueno'),
# (127, 22125.77, 2, 'Regular'),
# (128, 66080.53, 3, 'Regular'),
# (129, 7676.32, 5, 'Bueno'),
# (130, 65285.71, 1, 'Regular'),
# (131, 19067.03, 3, 'Malo'),
# (132, 88593.86, 3, 'Bueno'),
# (133, 15748.37, 4, 'Malo'),
# (134, 76606.8, 3, 'Bueno'),
# (135, 20522.12, 1, 'Bueno'),
# (136, 27703.92, 4, 'Bueno'),
# (137, 44196.98, 1, 'Regular'),
# (138, 60155.77, 1, 'Malo'),
# (139, 84823.99, 4, 'Bueno'),
# (140, 34316.32, 1, 'Bueno'),
# (141, 45658.29, 3, 'Bueno'),
# (142, 30122.27, 2, 'Regular'),
# (143, 19992.69, 5, 'Malo'),
# (144, 16958.0, 5, 'Regular'),
# (145, 71266.82, 2, 'Bueno'),
# (146, 67052.6, 5, 'Bueno'),
# (147, 41089.78, 1, 'Bueno'),
# (148, 95683.91, 5, 'Bueno'),
# (149, 73937.47, 5, 'Bueno'),
# (150, 17247.91, 4, 'Malo'),
# (151, 0, 0, 'Bueno'),
# (152, 0, 0, 'Bueno'),
# (153, 80979.25, 3, 'Bueno'),
# (154, 60472.83, 4, 'Bueno'),
# (155, 76158.8, 3, 'Regular'),
# (156, 3192.36, 4, 'Malo'),
# (157, 7975.37, 3, 'Bueno'),
# (158, 45443.17, 1, 'Bueno'),
# (159, 10683.52, 4, 'Bueno'),
# (160, 15432.86, 5, 'Regular'),
# (161, 11518.57, 3, 'Bueno'),
# (162, 15710.12, 3, 'Regular'),
# (163, 89933.05, 1, 'Regular'),
# (164, 0, 0, 'Bueno'),
# (165, 27100.65, 3, 'Bueno'),
# (166, 8207.09, 4, 'Bueno'),
# (167, 0, 0, 'Bueno'),
# (168, 65538.5, 4, 'Regular'),
# (169, 54798.55, 4, 'Bueno'),
# (170, 48714.45, 2, 'Bueno'),
# (171, 18208.6, 1, 'Bueno'),
# (172, 6966.84, 3, 'Bueno'),
# (173, 7653.19, 4, 'Bueno'),
# (174, 94391.17, 5, 'Bueno'),
# (175, 27049.92, 5, 'Regular'),
# (176, 54795.32, 1, 'Bueno'),
# (177, 82930.62, 5, 'Regular'),
# (178, 48573.99, 5, 'Malo'),
# (179, 17324.62, 4, 'Bueno'),
# (180, 50780.62, 5, 'Bueno'),
# (181, 0, 0, 'Bueno'),
# (182, 99093.76, 3, 'Bueno'),
# (183, 4106.89, 4, 'Bueno'),
# (184, 0, 0, 'Bueno'),
# (185, 0, 0, 'Bueno'),
# (186, 75348.06, 1, 'Bueno'),
# (187, 66135.07, 3, 'Regular'),
# (188, 41141.92, 3, 'Bueno'),
# (189, 30580.86, 4, 'Bueno'),
# (190, 17629.23, 2, 'Bueno'),
# (191, 12926.0, 1, 'Regular'),
# (192, 35226.15, 5, 'Bueno'),
# (193, 40383.73, 4, 'Regular'),
# (194, 57785.4, 5, 'Bueno'),
# (195, 72331.16, 1, 'Bueno'),
# (196, 11645.82, 3, 'Bueno'),
# (197, 36257.06, 4, 'Regular'),
# (198, 0, 0, 'Bueno'),
# (199, 5084.79, 3, 'Bueno'),
# (200, 28503.58, 5, 'Bueno'),
