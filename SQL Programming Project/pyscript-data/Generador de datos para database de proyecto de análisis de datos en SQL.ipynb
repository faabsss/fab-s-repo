# %%
import random
from datetime import datetime, timedelta

# TABLA 1: Clientes
def generar_fecha_nacimiento():
    inicio = datetime(1970, 1, 1)
    fin = datetime(2000, 12, 31)
    return inicio + timedelta(days=random.randint(0, (fin - inicio).days))

clientes_data = []
for cliente_id in range(1, 201):  # 200 clientes
    sexo = random.choice(['M', 'F'])
    fecha_nacimiento = generar_fecha_nacimiento().strftime('%Y-%m-%d')
    ingreso_mensual = round(random.uniform(1500, 10000), 2)  # Ingresos entre 1,500 y 10,000
    # Cada registro: (ID_Cliente, Sexo, Fecha_Nacimiento, Ingreso)
    clientes_data.append((cliente_id, sexo, fecha_nacimiento, ingreso_mensual))

# %%
# TABLA 2: Solicitudes de Crédito
solicitudes_data = []
for cliente_id, _, _, ingreso in clientes_data:
    monto_maximo = ingreso * 5  # El cliente puede solicitar hasta 5 veces su ingreso
    monto_solicitado = round(random.uniform(1000, min(monto_maximo, 50000)), 2)
    plazo_meses = random.choice([12, 24, 36, 48, 60])
    # La tasa se ajusta: menor ingreso → tasa mayor; se resta un valor proporcional al ingreso
    tasa_interes = round(random.uniform(5.0, 20.0) - (ingreso / 5000) * 3, 2)
    tasa_interes = max(3.5, tasa_interes)  # Límite mínimo de 3.5%
    # Cada registro: (ID_Cliente, Monto_Solicitado, Plazo_Meses, Tasa_Interes)
    solicitudes_data.append((cliente_id, monto_solicitado, plazo_meses, tasa_interes))

# %%
# TABLA 3: Evaluaciones de Riesgo
evaluaciones_data = []
estados_solicitud = []  # Almacenará (ID_Solicitud, Estado)
for idx, (id_cliente, monto, plazo, tasa) in enumerate(solicitudes_data, start=1):
    # Buscar ingreso del cliente (en clientes_data, ingreso está en posición 3)
    ingreso_cliente = [c[3] for c in clientes_data if c[0] == id_cliente][0]
    # Calcular score en función del ingreso:
    # El score se escala entre 300 y 900: mayor ingreso → score más alto
    score_riesgo = min(900, max(300, int((ingreso_cliente / 10000) * 600 + 300)))
    if score_riesgo >= 750:
        nivel_riesgo = 'Bajo'
    elif score_riesgo >= 500:
        nivel_riesgo = 'Medio'
    else:
        nivel_riesgo = 'Alto'
    comentarios = f"Evaluación de riesgo: {nivel_riesgo}."
    # Cada registro: (ID_Solicitud, Score_Riesgo, Nivel_Riesgo, Comentarios)
    

    # Determinar estado de la solicitud basado en el nivel de riesgo
    if nivel_riesgo == 'Bajo':
        estado = 'Aprobado'
    elif nivel_riesgo == 'Medio':
        estado = random.choices(['Aprobado', 'Pendiente'], weights=[0.6, 0.4])[0]
    else:
        estado = 'Rechazado'
    estados_solicitud.append((idx, estado))
    evaluaciones_data.append((idx, score_riesgo, nivel_riesgo, estado, comentarios))

# %%
# TABLA 4: Pagos
pagos_data = []
for id_solicitud, estado in estados_solicitud:
    if estado == 'Aprobado':
        num_pagos = random.randint(1, 12)  # Entre 1 y 12 pagos registrados
        for _ in range(num_pagos):
            monto_pagado = round(random.uniform(100, 2000), 2)
            metodo_pago = random.choice(['Transferencia', 'Tarjeta', 'Efectivo'])
            # Cada registro: (ID_Solicitud, Monto_Pagado, Método_Pago)
            pagos_data.append((id_solicitud, monto_pagado, metodo_pago))

# %%
# TABLA 5: Historial Crediticio
historial_crediticio_data = []
for cliente_id in range(1, 201):
    cantidad_prestamos = random.randint(0, 5)  # Entre 0 y 5 préstamos previos
    monto_total = round(random.uniform(1000, 100000), 2) if cantidad_prestamos > 0 else 0
    historial_pagos = random.choices(['Bueno', 'Regular', 'Malo'], weights=[0.6, 0.3, 0.1])[0] if cantidad_prestamos > 0 else 'Bueno'
    # Cada registro: (ID_Cliente, Monto_Total, Cantidad_Prestamos, Historial_Pagos)
    historial_crediticio_data.append((cliente_id, monto_total, cantidad_prestamos, historial_pagos))

# %%
# Mostrar resultados
print("Tabla 1: Clientes")
for row in clientes_data:
    print(f"{row},")

print("\nTabla 2: Solicitudes de crédito")
for row in solicitudes_data:
    print(f"{row},")

print("\nTabla 3: Evaluaciones de riesgo")
for row in evaluaciones_data:
    print(f"{row},")

print("\nTabla 4: Pagos")
for row in pagos_data:
    print(f"{row},")

print("\nTabla 5: Historial crediticio")
for row in historial_crediticio_data:
    print(f"{row},")
# Out:
# Tabla 1: Clientes
# (1, 'M', '1990-08-14', 5715.42),
# (2, 'M', '1979-09-08', 4296.17),
# (3, 'M', '1975-10-23', 4345.27),
# (4, 'F', '1980-09-02', 2509.91),
# (5, 'F', '1973-01-18', 8624.38),
# (6, 'M', '1995-10-08', 9193.8),
# (7, 'F', '1981-12-06', 6153.58),
# (8, 'M', '1977-05-22', 5239.8),
# (9, 'M', '1983-07-18', 2596.64),
# (10, 'M', '1981-08-21', 5940.17),
# (11, 'F', '1984-01-05', 3740.44),
# (12, 'F', '1986-05-17', 6108.87),
# (13, 'F', '1978-02-11', 2527.94),
# (14, 'M', '1998-11-30', 8833.72),
# (15, 'M', '1981-11-27', 8192.48),
# (16, 'F', '1996-10-19', 4706.85),
# (17, 'F', '1976-05-22', 3122.14),
# (18, 'F', '1980-10-12', 9958.45),
# (19, 'F', '1993-04-10', 3719.03),
# (20, 'M', '1976-07-12', 6817.45),
# (21, 'F', '1998-02-24', 5050.66),
# (22, 'M', '1971-10-14', 3397.06),
# (23, 'F', '1984-03-19', 3459.05),
# (24, 'F', '1974-10-10', 7671.9),
# (25, 'F', '1983-05-19', 8204.82),
# (26, 'F', '1985-03-30', 7673.13),
# (27, 'F', '1995-02-17', 4771.84),
# (28, 'M', '1999-10-16', 6306.8),
# (29, 'F', '1980-09-19', 6799.13),
# (30, 'M', '1977-11-29', 4387.1),
# (31, 'M', '1972-12-15', 1687.96),
# (32, 'F', '1980-06-29', 4112.08),
# (33, 'M', '1981-07-10', 4570.55),
# (34, 'F', '2000-10-19', 4059.37),
# (35, 'F', '1995-01-20', 4407.12),
# (36, 'M', '1974-11-22', 6353.74),
# (37, 'M', '1974-06-16', 5366.47),
# (38, 'F', '1979-09-12', 6889.76),
# (39, 'M', '2000-02-25', 7619.45),
# (40, 'F', '1986-08-12', 6619.28),
# (41, 'M', '1979-12-03', 3643.54),
# (42, 'F', '1990-03-05', 2838.13),
# (43, 'F', '1989-11-06', 9422.31),
# (44, 'M', '1992-03-11', 5202.34),
# (45, 'M', '1983-10-04', 2696.07),
# (46, 'F', '1978-08-25', 1877.79),
# (47, 'M', '1983-12-09', 5424.93),
# (48, 'M', '1991-06-20', 4655.77),
# (49, 'F', '1991-08-04', 6183.06),
# (50, 'M', '1990-12-17', 7438.81),
# (51, 'M', '1977-02-24', 2590.74),
# (52, 'M', '1994-09-21', 3846.49),
# (53, 'F', '1998-01-21', 8310.01),
# (54, 'F', '1998-06-22', 6547.67),
# (55, 'F', '1989-10-07', 3184.15),
# (56, 'F', '1993-03-30', 7794.39),
# (57, 'M', '1978-02-01', 9475.75),
# (58, 'M', '1979-11-07', 4035.06),
# (59, 'F', '1993-06-05', 9379.76),
# (60, 'F', '1975-05-16', 5346.53),
# (61, 'F', '1995-06-09', 4570.19),
# (62, 'M', '1992-11-03', 6245.51),
# (63, 'F', '1995-07-09', 1652.54),
# (64, 'F', '1994-11-03', 9063.42),
# (65, 'M', '1980-12-23', 4810.3),
# (66, 'M', '1982-04-17', 2382.82),
# (67, 'M', '1997-08-06', 2115.74),
# (68, 'F', '1992-03-06', 4086.91),
# (69, 'M', '1984-03-10', 2306.57),
# (70, 'F', '1984-09-11', 7586.64),
# (71, 'M', '1976-09-02', 3012.12),
# (72, 'M', '1971-03-10', 2431.81),
# (73, 'F', '1981-03-23', 6282.22),
# (74, 'M', '1998-07-21', 4035.5),
# (75, 'M', '1992-10-13', 2910.05),
# (76, 'F', '1976-06-12', 3905.54),
# (77, 'M', '1974-07-17', 4647.39),
# (78, 'F', '1989-10-20', 1799.51),
# (79, 'F', '1975-09-27', 8045.85),
# (80, 'M', '1995-10-09', 6215.44),
# (81, 'M', '1993-06-25', 3237.26),
# (82, 'F', '1982-09-24', 8153.39),
# (83, 'M', '1994-04-13', 6930.83),
# (84, 'M', '1974-12-08', 2523.49),
# (85, 'M', '1987-04-20', 7883.33),
# (86, 'M', '1978-04-16', 5537.13),
# (87, 'M', '1989-11-25', 2140.93),
# (88, 'F', '1988-09-20', 9885.49),
# (89, 'F', '1975-03-29', 3662.28),
# (90, 'M', '1977-08-29', 8051.79),
# (91, 'F', '1990-01-28', 9751.71),
# (92, 'F', '1977-10-19', 4298.98),
# (93, 'F', '1976-08-11', 4544.59),
# (94, 'M', '1970-05-18', 1713.81),
# (95, 'M', '1982-02-24', 5154.03),
# (96, 'F', '1997-06-05', 3583.92),
# (97, 'M', '1985-07-16', 6646.96),
# (98, 'F', '1982-05-14', 8708.53),
# (99, 'F', '1975-05-07', 6243.8),
# (100, 'M', '1985-04-22', 3980.44),
# (101, 'M', '1974-06-26', 6814.81),
# (102, 'M', '1989-06-27', 9736.51),
# (103, 'F', '1992-08-22', 6788.67),
# (104, 'F', '1971-03-20', 5100.81),
# (105, 'F', '1970-10-19', 8347.5),
# (106, 'M', '1997-08-23', 7847.62),
# (107, 'M', '1983-08-21', 2511.66),
# (108, 'F', '1982-09-01', 6182.71),
# (109, 'F', '1976-10-28', 9318.84),
# (110, 'F', '1977-12-12', 2703.11),
# (111, 'M', '1976-06-04', 8648.12),
# (112, 'M', '1980-07-03', 3016.43),
# (113, 'M', '1984-02-27', 6119.3),
# (114, 'F', '1995-06-09', 3278.43),
# (115, 'M', '1993-01-25', 6126.58),
# (116, 'M', '1974-05-22', 2955.48),
# (117, 'F', '1978-03-02', 7646.1),
# (118, 'F', '1986-03-22', 7685.48),
# (119, 'M', '1990-08-28', 4565.87),
# (120, 'M', '1998-11-13', 6119.06),
# (121, 'F', '1996-02-09', 5528.9),
# (122, 'M', '1986-08-03', 7438.49),
# (123, 'F', '1999-07-07', 8685.75),
# (124, 'M', '1987-11-08', 3986.88),
# (125, 'M', '1974-01-19', 1687.24),
# (126, 'M', '1990-01-29', 4914.63),
# (127, 'F', '1994-03-01', 4954.25),
# (128, 'M', '1982-01-15', 6425.38),
# (129, 'M', '1995-05-13', 8244.0),
# (130, 'M', '1981-10-28', 8853.73),
# (131, 'F', '1976-08-21', 8318.77),
# (132, 'M', '1992-01-27', 7927.48),
# (133, 'M', '1978-02-18', 6135.71),
# (134, 'F', '1976-08-08', 3525.23),
# (135, 'F', '1988-03-19', 8356.11),
# (136, 'M', '2000-07-14', 8601.66),
# (137, 'F', '1974-05-30', 7325.8),
# (138, 'M', '1976-09-27', 9855.6),
# (139, 'F', '1981-04-01', 7360.28),
# (140, 'F', '1977-05-19', 2256.16),
# (141, 'M', '1991-05-29', 2979.41),
# (142, 'M', '1991-12-22', 4342.15),
# (143, 'F', '1970-03-11', 6928.44),
# (144, 'M', '1973-05-04', 7796.24),
# (145, 'M', '1996-12-28', 6458.58),
# (146, 'M', '1983-07-18', 2478.01),
# (147, 'M', '1999-04-22', 2703.21),
# (148, 'F', '1970-04-25', 7180.37),
# (149, 'M', '1972-04-07', 5555.89),
# (150, 'M', '1971-05-05', 4715.29),
# (151, 'F', '1994-08-24', 6859.34),
# (152, 'M', '1971-01-07', 4331.21),
# (153, 'F', '1996-06-30', 6462.29),
# (154, 'M', '1982-02-24', 8356.18),
# (155, 'M', '1974-12-18', 8275.11),
# (156, 'M', '1995-06-02', 5729.64),
# (157, 'F', '2000-08-14', 4661.29),
# (158, 'F', '1993-09-05', 7247.56),
# (159, 'M', '1977-11-04', 8424.26),
# (160, 'M', '1991-12-12', 6488.46),
# (161, 'F', '1991-11-02', 9149.37),
# (162, 'M', '1996-08-25', 1786.89),
# (163, 'F', '1999-12-27', 3654.81),
# (164, 'M', '1982-08-21', 5959.52),
# (165, 'M', '1991-06-30', 1789.28),
# (166, 'M', '1971-11-01', 5970.57),
# (167, 'F', '1976-12-21', 1626.93),
# (168, 'M', '1989-07-20', 4174.57),
# (169, 'M', '1998-07-02', 4512.42),
# (170, 'M', '1982-06-20', 7571.32),
# (171, 'M', '1983-12-24', 4764.81),
# (172, 'F', '1996-06-15', 4092.73),
# (173, 'M', '1981-09-13', 4684.25),
# (174, 'M', '1995-04-24', 8028.42),
# (175, 'M', '1973-01-01', 9503.03),
# (176, 'M', '1973-01-03', 4068.76),
# (177, 'F', '1991-06-04', 5843.68),
# (178, 'F', '1992-07-15', 5456.41),
# (179, 'M', '1991-08-05', 1954.3),
# (180, 'F', '1984-05-11', 6035.64),
# (181, 'F', '1995-03-12', 9134.48),
# (182, 'F', '1970-10-28', 1819.47),
# (183, 'F', '1979-05-30', 9610.06),
# (184, 'M', '1983-12-05', 3928.68),
# (185, 'M', '1992-03-15', 1939.63),
# (186, 'F', '1973-01-09', 2281.19),
# (187, 'F', '1982-02-08', 9865.12),
# (188, 'M', '1988-01-17', 1575.18),
# (189, 'F', '1989-08-04', 9343.18),
# (190, 'F', '1993-03-14', 7543.67),
# (191, 'M', '1981-03-13', 8311.47),
# (192, 'F', '1990-02-02', 2437.46),
# (193, 'F', '1991-10-17', 7866.8),
# (194, 'F', '2000-02-21', 7150.66),
# (195, 'F', '1972-02-18', 9070.52),
# (196, 'M', '1982-09-02', 6000.64),
# (197, 'F', '1992-11-07', 4391.21),
# (198, 'F', '1982-04-30', 4635.75),
# (199, 'F', '1993-08-13', 9131.3),
# (200, 'M', '1995-05-30', 6211.73),
#
# Tabla 2: Solicitudes de crédito
# (1, 2990.73, 48, 9.4),
# (2, 18823.87, 12, 15.52),
# (3, 3094.41, 60, 11.17),
# (4, 33255.84, 60, 8.07),
# (5, 46862.0, 48, 8.15),
# (6, 4517.33, 24, 13.2),
# (7, 6690.54, 24, 8.19),
# (8, 8327.12, 24, 7.91),
# (9, 33064.63, 12, 3.5),
# (10, 27863.25, 12, 11.16),
# (11, 6661.02, 60, 7.17),
# (12, 11668.18, 60, 7.89),
# (13, 5001.49, 60, 17.75),
# (14, 4031.56, 36, 3.5),
# (15, 35417.92, 12, 12.68),
# (16, 13941.14, 36, 10.63),
# (17, 13700.72, 12, 6.57),
# (18, 1715.56, 24, 9.59),
# (19, 32167.9, 48, 3.5),
# (20, 41224.37, 24, 3.5),
# (21, 7485.05, 48, 12.62),
# (22, 1434.26, 24, 4.37),
# (23, 1316.06, 60, 9.36),
# (24, 18618.33, 36, 10.43),
# (25, 12252.61, 24, 8.55),
# (26, 9634.99, 60, 8.71),
# (27, 4972.6, 48, 15.32),
# (28, 17985.26, 60, 10.28),
# (29, 22999.53, 24, 12.6),
# (30, 40325.03, 60, 3.5),
# (31, 19192.94, 24, 11.03),
# (32, 18068.51, 24, 14.1),
# (33, 1897.08, 24, 12.44),
# (34, 11393.98, 60, 15.13),
# (35, 12984.64, 12, 8.87),
# (36, 13787.43, 12, 7.67),
# (37, 12383.09, 24, 10.3),
# (38, 8653.2, 36, 16.79),
# (39, 29226.44, 24, 7.89),
# (40, 17562.37, 48, 5.26),
# (41, 14428.18, 36, 10.33),
# (42, 14429.37, 24, 3.5),
# (43, 4830.87, 12, 12.46),
# (44, 32994.38, 36, 14.92),
# (45, 27283.28, 24, 11.15),
# (46, 5923.21, 24, 7.69),
# (47, 37897.29, 12, 11.38),
# (48, 27477.45, 48, 13.67),
# (49, 12375.31, 60, 8.97),
# (50, 4805.34, 36, 5.24),
# (51, 35220.12, 12, 4.58),
# (52, 5200.58, 60, 12.89),
# (53, 9472.68, 24, 3.5),
# (54, 10616.17, 36, 3.5),
# (55, 5832.79, 48, 13.1),
# (56, 2304.73, 48, 3.5),
# (57, 1046.73, 24, 12.3),
# (58, 21198.21, 24, 13.07),
# (59, 28965.46, 24, 4.32),
# (60, 5864.08, 60, 3.52),
# (61, 20504.62, 48, 5.15),
# (62, 4820.81, 12, 10.82),
# (63, 4489.52, 12, 16.12),
# (64, 22003.15, 60, 4.53),
# (65, 9948.59, 60, 17.17),
# (66, 5178.29, 48, 4.48),
# (67, 3265.0, 12, 17.61),
# (68, 41159.8, 60, 9.53),
# (69, 19709.62, 48, 6.0),
# (70, 16797.9, 60, 11.03),
# (71, 24963.34, 48, 3.5),
# (72, 2000.96, 36, 17.0),
# (73, 8519.21, 48, 4.51),
# (74, 2752.81, 24, 6.53),
# (75, 24388.74, 60, 9.19),
# (76, 6735.7, 48, 15.39),
# (77, 9304.58, 24, 11.68),
# (78, 6176.22, 24, 8.55),
# (79, 21046.3, 60, 14.34),
# (80, 14946.89, 12, 3.98),
# (81, 31330.74, 24, 4.86),
# (82, 12985.06, 60, 10.54),
# (83, 4117.04, 12, 3.5),
# (84, 12484.76, 24, 13.11),
# (85, 24559.24, 24, 3.5),
# (86, 23701.92, 48, 11.52),
# (87, 20743.09, 48, 11.75),
# (88, 5142.54, 60, 14.7),
# (89, 8468.73, 48, 12.46),
# (90, 17477.56, 48, 6.75),
# (91, 15794.44, 60, 12.85),
# (92, 8750.55, 12, 13.0),
# (93, 3745.12, 48, 3.5),
# (94, 29415.81, 48, 3.5),
# (95, 30625.95, 36, 15.16),
# (96, 20848.18, 24, 5.45),
# (97, 1371.48, 12, 13.84),
# (98, 4050.77, 48, 7.72),
# (99, 7259.22, 12, 15.48),
# (100, 1017.91, 48, 4.2),
# (101, 15848.81, 60, 8.19),
# (102, 12757.94, 12, 13.92),
# (103, 9431.03, 24, 15.92),
# (104, 16217.46, 36, 13.7),
# (105, 19280.2, 12, 3.5),
# (106, 6811.54, 36, 10.03),
# (107, 11442.3, 36, 10.96),
# (108, 5897.76, 24, 7.2),
# (109, 20051.65, 12, 7.86),
# (110, 12138.11, 12, 5.26),
# (111, 10982.49, 24, 17.08),
# (112, 25142.02, 24, 11.37),
# (113, 31287.43, 60, 5.65),
# (114, 17448.62, 36, 8.98),
# (115, 37979.74, 48, 5.64),
# (116, 9775.09, 36, 4.59),
# (117, 8754.66, 24, 16.33),
# (118, 5381.02, 36, 10.2),
# (119, 5134.41, 24, 6.74),
# (120, 25725.49, 48, 15.08),
# (121, 19874.31, 60, 11.86),
# (122, 1710.69, 12, 4.4),
# (123, 16859.75, 48, 3.5),
# (124, 4673.67, 36, 6.8),
# (125, 13889.3, 36, 6.29),
# (126, 3159.14, 36, 10.73),
# (127, 32966.18, 60, 4.92),
# (128, 33290.87, 24, 8.86),
# (129, 11748.15, 24, 7.11),
# (130, 31199.6, 60, 3.5),
# (131, 3911.94, 24, 9.32),
# (132, 16513.36, 12, 12.39),
# (133, 9395.93, 36, 10.26),
# (134, 10137.49, 24, 18.03),
# (135, 28753.93, 48, 3.5),
# (136, 4050.66, 24, 8.94),
# (137, 10494.46, 48, 11.37),
# (138, 23139.29, 12, 14.33),
# (139, 31198.96, 48, 3.55),
# (140, 4798.4, 60, 12.03),
# (141, 30944.63, 24, 6.31),
# (142, 22653.73, 60, 15.54),
# (143, 11388.44, 48, 17.9),
# (144, 26863.19, 24, 4.22),
# (145, 11612.37, 36, 12.15),
# (146, 7433.73, 60, 15.03),
# (147, 30298.3, 36, 9.74),
# (148, 25782.19, 60, 3.5),
# (149, 9528.86, 24, 13.98),
# (150, 16223.11, 48, 9.13),
# (151, 9996.53, 12, 8.15),
# (152, 3264.55, 12, 7.25),
# (153, 6475.66, 60, 3.91),
# (154, 32810.3, 60, 9.78),
# (155, 39296.86, 12, 11.56),
# (156, 23718.59, 24, 9.46),
# (157, 5539.7, 48, 12.0),
# (158, 23995.81, 12, 5.86),
# (159, 26194.82, 12, 10.07),
# (160, 7606.08, 48, 12.27),
# (161, 19173.46, 60, 4.93),
# (162, 3871.94, 60, 7.73),
# (163, 4069.83, 12, 4.4),
# (164, 10579.8, 36, 6.32),
# (165, 12568.93, 36, 5.57),
# (166, 13753.68, 36, 13.5),
# (167, 2084.16, 12, 7.21),
# (168, 32802.56, 24, 6.34),
# (169, 36134.93, 36, 7.19),
# (170, 1810.45, 12, 13.83),
# (171, 8726.99, 48, 15.69),
# (172, 13849.84, 48, 15.8),
# (173, 29791.13, 60, 9.09),
# (174, 29578.9, 12, 4.69),
# (175, 10491.61, 24, 14.36),
# (176, 24872.6, 48, 4.47),
# (177, 13391.21, 12, 5.51),
# (178, 1562.05, 60, 12.34),
# (179, 25019.84, 36, 13.47),
# (180, 4531.07, 24, 10.92),
# (181, 12300.96, 12, 16.92),
# (182, 5301.27, 60, 12.45),
# (183, 5706.3, 48, 7.06),
# (184, 2462.98, 12, 6.55),
# (185, 30284.88, 12, 6.62),
# (186, 21167.86, 24, 10.72),
# (187, 12422.56, 36, 3.5),
# (188, 3552.5, 12, 6.91),
# (189, 14929.95, 12, 7.2),
# (190, 31366.3, 36, 5.56),
# (191, 16759.87, 12, 16.25),
# (192, 18176.34, 36, 6.31),
# (193, 2768.17, 36, 13.26),
# (194, 10351.5, 24, 16.0),
# (195, 2111.95, 48, 5.7),
# (196, 28599.06, 36, 14.02),
# (197, 31856.57, 24, 3.5),
# (198, 15049.13, 48, 17.3),
# (199, 2301.3, 48, 8.67),
# (200, 20819.43, 36, 8.73),
#
# Tabla 3: Evaluaciones de riesgo
# (1, 642, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (2, 557, 'Medio', 'Pendiente', 'Evaluación de riesgo: Medio.'),
# (3, 560, 'Medio', 'Pendiente', 'Evaluación de riesgo: Medio.'),
# (4, 450, 'Alto', 'Rechazado', 'Evaluación de riesgo: Alto.'),
# (5, 817, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (6, 851, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (7, 669, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (8, 614, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (9, 455, 'Alto', 'Rechazado', 'Evaluación de riesgo: Alto.'),
# (10, 656, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (11, 524, 'Medio', 'Pendiente', 'Evaluación de riesgo: Medio.'),
# (12, 666, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (13, 451, 'Alto', 'Rechazado', 'Evaluación de riesgo: Alto.'),
# (14, 830, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (15, 791, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (16, 582, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (17, 487, 'Alto', 'Rechazado', 'Evaluación de riesgo: Alto.'),
# (18, 897, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (19, 523, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (20, 709, 'Medio', 'Pendiente', 'Evaluación de riesgo: Medio.'),
# (21, 603, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (22, 503, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (23, 507, 'Medio', 'Pendiente', 'Evaluación de riesgo: Medio.'),
# (24, 760, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (25, 792, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (26, 760, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (27, 586, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (28, 678, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (29, 707, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (30, 563, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (31, 401, 'Alto', 'Rechazado', 'Evaluación de riesgo: Alto.'),
# (32, 546, 'Medio', 'Pendiente', 'Evaluación de riesgo: Medio.'),
# (33, 574, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (34, 543, 'Medio', 'Pendiente', 'Evaluación de riesgo: Medio.'),
# (35, 564, 'Medio', 'Pendiente', 'Evaluación de riesgo: Medio.'),
# (36, 681, 'Medio', 'Pendiente', 'Evaluación de riesgo: Medio.'),
# (37, 621, 'Medio', 'Pendiente', 'Evaluación de riesgo: Medio.'),
# (38, 713, 'Medio', 'Pendiente', 'Evaluación de riesgo: Medio.'),
# (39, 757, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (40, 697, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (41, 518, 'Medio', 'Pendiente', 'Evaluación de riesgo: Medio.'),
# (42, 470, 'Alto', 'Rechazado', 'Evaluación de riesgo: Alto.'),
# (43, 865, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (44, 612, 'Medio', 'Pendiente', 'Evaluación de riesgo: Medio.'),
# (45, 461, 'Alto', 'Rechazado', 'Evaluación de riesgo: Alto.'),
# (46, 412, 'Alto', 'Rechazado', 'Evaluación de riesgo: Alto.'),
# (47, 625, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (48, 579, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (49, 670, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (50, 746, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (51, 455, 'Alto', 'Rechazado', 'Evaluación de riesgo: Alto.'),
# (52, 530, 'Medio', 'Pendiente', 'Evaluación de riesgo: Medio.'),
# (53, 798, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (54, 692, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (55, 491, 'Alto', 'Rechazado', 'Evaluación de riesgo: Alto.'),
# (56, 767, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (57, 868, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (58, 542, 'Medio', 'Pendiente', 'Evaluación de riesgo: Medio.'),
# (59, 862, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (60, 620, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (61, 574, 'Medio', 'Pendiente', 'Evaluación de riesgo: Medio.'),
# (62, 674, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (63, 399, 'Alto', 'Rechazado', 'Evaluación de riesgo: Alto.'),
# (64, 843, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (65, 588, 'Medio', 'Pendiente', 'Evaluación de riesgo: Medio.'),
# (66, 442, 'Alto', 'Rechazado', 'Evaluación de riesgo: Alto.'),
# (67, 426, 'Alto', 'Rechazado', 'Evaluación de riesgo: Alto.'),
# (68, 545, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (69, 438, 'Alto', 'Rechazado', 'Evaluación de riesgo: Alto.'),
# (70, 755, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (71, 480, 'Alto', 'Rechazado', 'Evaluación de riesgo: Alto.'),
# (72, 445, 'Alto', 'Rechazado', 'Evaluación de riesgo: Alto.'),
# (73, 676, 'Medio', 'Pendiente', 'Evaluación de riesgo: Medio.'),
# (74, 542, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (75, 474, 'Alto', 'Rechazado', 'Evaluación de riesgo: Alto.'),
# (76, 534, 'Medio', 'Pendiente', 'Evaluación de riesgo: Medio.'),
# (77, 578, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (78, 407, 'Alto', 'Rechazado', 'Evaluación de riesgo: Alto.'),
# (79, 782, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (80, 672, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (81, 494, 'Alto', 'Rechazado', 'Evaluación de riesgo: Alto.'),
# (82, 789, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (83, 715, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (84, 451, 'Alto', 'Rechazado', 'Evaluación de riesgo: Alto.'),
# (85, 772, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (86, 632, 'Medio', 'Pendiente', 'Evaluación de riesgo: Medio.'),
# (87, 428, 'Alto', 'Rechazado', 'Evaluación de riesgo: Alto.'),
# (88, 893, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (89, 519, 'Medio', 'Pendiente', 'Evaluación de riesgo: Medio.'),
# (90, 783, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (91, 885, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (92, 557, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (93, 572, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (94, 402, 'Alto', 'Rechazado', 'Evaluación de riesgo: Alto.'),
# (95, 609, 'Medio', 'Pendiente', 'Evaluación de riesgo: Medio.'),
# (96, 515, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (97, 698, 'Medio', 'Pendiente', 'Evaluación de riesgo: Medio.'),
# (98, 822, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (99, 674, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (100, 538, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (101, 708, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (102, 884, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (103, 707, 'Medio', 'Pendiente', 'Evaluación de riesgo: Medio.'),
# (104, 606, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (105, 800, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (106, 770, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (107, 450, 'Alto', 'Rechazado', 'Evaluación de riesgo: Alto.'),
# (108, 670, 'Medio', 'Pendiente', 'Evaluación de riesgo: Medio.'),
# (109, 859, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (110, 462, 'Alto', 'Rechazado', 'Evaluación de riesgo: Alto.'),
# (111, 818, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (112, 480, 'Alto', 'Rechazado', 'Evaluación de riesgo: Alto.'),
# (113, 667, 'Medio', 'Pendiente', 'Evaluación de riesgo: Medio.'),
# (114, 496, 'Alto', 'Rechazado', 'Evaluación de riesgo: Alto.'),
# (115, 667, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (116, 477, 'Alto', 'Rechazado', 'Evaluación de riesgo: Alto.'),
# (117, 758, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (118, 761, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (119, 573, 'Medio', 'Pendiente', 'Evaluación de riesgo: Medio.'),
# (120, 667, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (121, 631, 'Medio', 'Pendiente', 'Evaluación de riesgo: Medio.'),
# (122, 746, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (123, 821, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (124, 539, 'Medio', 'Pendiente', 'Evaluación de riesgo: Medio.'),
# (125, 401, 'Alto', 'Rechazado', 'Evaluación de riesgo: Alto.'),
# (126, 594, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (127, 597, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (128, 685, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (129, 794, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (130, 831, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (131, 799, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (132, 775, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (133, 668, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (134, 511, 'Medio', 'Pendiente', 'Evaluación de riesgo: Medio.'),
# (135, 801, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (136, 816, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (137, 739, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (138, 891, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (139, 741, 'Medio', 'Pendiente', 'Evaluación de riesgo: Medio.'),
# (140, 435, 'Alto', 'Rechazado', 'Evaluación de riesgo: Alto.'),
# (141, 478, 'Alto', 'Rechazado', 'Evaluación de riesgo: Alto.'),
# (142, 560, 'Medio', 'Pendiente', 'Evaluación de riesgo: Medio.'),
# (143, 715, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (144, 767, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (145, 687, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (146, 448, 'Alto', 'Rechazado', 'Evaluación de riesgo: Alto.'),
# (147, 462, 'Alto', 'Rechazado', 'Evaluación de riesgo: Alto.'),
# (148, 730, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (149, 633, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (150, 582, 'Medio', 'Pendiente', 'Evaluación de riesgo: Medio.'),
# (151, 711, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (152, 559, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (153, 687, 'Medio', 'Pendiente', 'Evaluación de riesgo: Medio.'),
# (154, 801, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (155, 796, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (156, 643, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (157, 579, 'Medio', 'Pendiente', 'Evaluación de riesgo: Medio.'),
# (158, 734, 'Medio', 'Pendiente', 'Evaluación de riesgo: Medio.'),
# (159, 805, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (160, 689, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (161, 848, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (162, 407, 'Alto', 'Rechazado', 'Evaluación de riesgo: Alto.'),
# (163, 519, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (164, 657, 'Medio', 'Pendiente', 'Evaluación de riesgo: Medio.'),
# (165, 407, 'Alto', 'Rechazado', 'Evaluación de riesgo: Alto.'),
# (166, 658, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (167, 397, 'Alto', 'Rechazado', 'Evaluación de riesgo: Alto.'),
# (168, 550, 'Medio', 'Pendiente', 'Evaluación de riesgo: Medio.'),
# (169, 570, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (170, 754, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (171, 585, 'Medio', 'Pendiente', 'Evaluación de riesgo: Medio.'),
# (172, 545, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (173, 581, 'Medio', 'Pendiente', 'Evaluación de riesgo: Medio.'),
# (174, 781, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (175, 870, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (176, 544, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (177, 650, 'Medio', 'Pendiente', 'Evaluación de riesgo: Medio.'),
# (178, 627, 'Medio', 'Pendiente', 'Evaluación de riesgo: Medio.'),
# (179, 417, 'Alto', 'Rechazado', 'Evaluación de riesgo: Alto.'),
# (180, 662, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (181, 848, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (182, 409, 'Alto', 'Rechazado', 'Evaluación de riesgo: Alto.'),
# (183, 876, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (184, 535, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (185, 416, 'Alto', 'Rechazado', 'Evaluación de riesgo: Alto.'),
# (186, 436, 'Alto', 'Rechazado', 'Evaluación de riesgo: Alto.'),
# (187, 891, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (188, 394, 'Alto', 'Rechazado', 'Evaluación de riesgo: Alto.'),
# (189, 860, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (190, 752, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (191, 798, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (192, 446, 'Alto', 'Rechazado', 'Evaluación de riesgo: Alto.'),
# (193, 772, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (194, 729, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (195, 844, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (196, 660, 'Medio', 'Pendiente', 'Evaluación de riesgo: Medio.'),
# (197, 563, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
# (198, 578, 'Medio', 'Pendiente', 'Evaluación de riesgo: Medio.'),
# (199, 847, 'Bajo', 'Aprobado', 'Evaluación de riesgo: Bajo.'),
# (200, 672, 'Medio', 'Aprobado', 'Evaluación de riesgo: Medio.'),
#
# Tabla 4: Pagos
# (1, 1284.03, 'Tarjeta'),
# (5, 1258.85, 'Tarjeta'),
# (5, 367.24, 'Efectivo'),
# (5, 1253.47, 'Tarjeta'),
# (5, 222.88, 'Tarjeta'),
# (5, 1456.48, 'Transferencia'),
# (6, 736.94, 'Efectivo'),
# (6, 1952.57, 'Transferencia'),
# (6, 1756.23, 'Transferencia'),
# (7, 1919.06, 'Tarjeta'),
# (7, 862.77, 'Tarjeta'),
# (7, 1522.96, 'Efectivo'),
# (7, 140.62, 'Efectivo'),
# (7, 667.45, 'Transferencia'),
# (8, 1454.48, 'Efectivo'),
# (8, 475.55, 'Tarjeta'),
# (8, 1207.33, 'Efectivo'),
# (8, 1809.1, 'Efectivo'),
# (8, 1321.78, 'Transferencia'),
# (8, 583.22, 'Transferencia'),
# (8, 1674.89, 'Efectivo'),
# (8, 483.47, 'Tarjeta'),
# (8, 995.53, 'Transferencia'),
# (10, 1776.62, 'Transferencia'),
# (10, 1387.16, 'Tarjeta'),
# (10, 676.18, 'Tarjeta'),
# (12, 486.96, 'Efectivo'),
# (12, 560.94, 'Efectivo'),
# (12, 743.22, 'Transferencia'),
# (12, 1202.93, 'Tarjeta'),
# (12, 1653.24, 'Tarjeta'),
# (12, 1258.48, 'Tarjeta'),
# (12, 104.79, 'Transferencia'),
# (12, 1525.84, 'Transferencia'),
# (12, 1871.14, 'Efectivo'),
# (12, 1905.9, 'Transferencia'),
# (12, 1983.55, 'Transferencia'),
# (12, 1199.34, 'Transferencia'),
# (14, 505.46, 'Efectivo'),
# (14, 390.69, 'Transferencia'),
# (14, 1321.3, 'Tarjeta'),
# (15, 1503.71, 'Efectivo'),
# (16, 1730.42, 'Efectivo'),
# (16, 1200.05, 'Efectivo'),
# (16, 1784.73, 'Efectivo'),
# (16, 1962.79, 'Transferencia'),
# (16, 146.81, 'Efectivo'),
# (18, 1602.4, 'Efectivo'),
# (18, 1689.7, 'Transferencia'),
# (18, 313.32, 'Transferencia'),
# (18, 1731.27, 'Transferencia'),
# (18, 1449.22, 'Efectivo'),
# (18, 1219.13, 'Efectivo'),
# (18, 1394.64, 'Tarjeta'),
# (18, 931.61, 'Efectivo'),
# (18, 1430.7, 'Tarjeta'),
# (18, 895.21, 'Efectivo'),
# (18, 1290.09, 'Transferencia'),
# (19, 227.97, 'Tarjeta'),
# (19, 1436.93, 'Tarjeta'),
# (19, 317.5, 'Transferencia'),
# (19, 538.73, 'Tarjeta'),
# (19, 311.97, 'Efectivo'),
# (19, 185.89, 'Tarjeta'),
# (19, 1010.53, 'Transferencia'),
# (19, 342.33, 'Efectivo'),
# (19, 1578.74, 'Efectivo'),
# (19, 1220.83, 'Tarjeta'),
# (21, 1725.37, 'Efectivo'),
# (21, 646.5, 'Transferencia'),
# (21, 633.05, 'Transferencia'),
# (21, 1641.17, 'Transferencia'),
# (21, 1661.48, 'Tarjeta'),
# (21, 604.12, 'Tarjeta'),
# (21, 1083.04, 'Transferencia'),
# (22, 143.72, 'Efectivo'),
# (22, 619.67, 'Efectivo'),
# (22, 1164.9, 'Efectivo'),
# (22, 651.98, 'Tarjeta'),
# (22, 1092.19, 'Efectivo'),
# (24, 1874.34, 'Efectivo'),
# (24, 163.41, 'Tarjeta'),
# (25, 802.86, 'Efectivo'),
# (25, 1799.61, 'Efectivo'),
# (25, 452.16, 'Tarjeta'),
# (25, 1805.19, 'Tarjeta'),
# (25, 1910.58, 'Tarjeta'),
# (25, 1550.51, 'Tarjeta'),
# (26, 137.87, 'Efectivo'),
# (26, 1649.01, 'Transferencia'),
# (26, 430.57, 'Tarjeta'),
# (26, 136.16, 'Transferencia'),
# (26, 1130.49, 'Efectivo'),
# (26, 1107.88, 'Tarjeta'),
# (26, 405.3, 'Transferencia'),
# (26, 1327.62, 'Efectivo'),
# (26, 775.9, 'Efectivo'),
# (26, 792.44, 'Transferencia'),
# (26, 779.75, 'Efectivo'),
# (27, 682.3, 'Tarjeta'),
# (27, 1746.49, 'Transferencia'),
# (27, 953.64, 'Tarjeta'),
# (27, 1884.31, 'Tarjeta'),
# (27, 1547.74, 'Efectivo'),
# (28, 1796.2, 'Efectivo'),
# (28, 1908.61, 'Tarjeta'),
# (28, 1552.94, 'Efectivo'),
# (28, 814.98, 'Efectivo'),
# (28, 1501.52, 'Tarjeta'),
# (28, 626.04, 'Efectivo'),
# (28, 1598.72, 'Tarjeta'),
# (28, 1495.99, 'Tarjeta'),
# (28, 1352.82, 'Efectivo'),
# (28, 255.5, 'Tarjeta'),
# (28, 1223.82, 'Efectivo'),
# (29, 386.01, 'Transferencia'),
# (30, 933.28, 'Transferencia'),
# (30, 908.45, 'Transferencia'),
# (30, 185.84, 'Tarjeta'),
# (33, 1928.64, 'Transferencia'),
# (33, 1447.4, 'Efectivo'),
# (33, 536.07, 'Transferencia'),
# (33, 574.01, 'Transferencia'),
# (33, 575.09, 'Transferencia'),
# (33, 1802.16, 'Tarjeta'),
# (33, 1687.35, 'Efectivo'),
# (39, 722.52, 'Tarjeta'),
# (39, 317.56, 'Efectivo'),
# (39, 1977.55, 'Transferencia'),
# (39, 1660.47, 'Transferencia'),
# (39, 1568.05, 'Transferencia'),
# (40, 432.73, 'Tarjeta'),
# (40, 173.59, 'Tarjeta'),
# (40, 671.7, 'Tarjeta'),
# (40, 649.1, 'Transferencia'),
# (43, 1633.86, 'Tarjeta'),
# (43, 430.12, 'Transferencia'),
# (43, 1631.87, 'Efectivo'),
# (43, 641.34, 'Tarjeta'),
# (43, 1719.19, 'Tarjeta'),
# (43, 364.54, 'Efectivo'),
# (43, 835.73, 'Efectivo'),
# (43, 911.83, 'Efectivo'),
# (47, 1838.81, 'Transferencia'),
# (47, 1298.59, 'Transferencia'),
# (47, 1823.8, 'Transferencia'),
# (47, 1763.14, 'Transferencia'),
# (47, 1526.66, 'Tarjeta'),
# (47, 640.87, 'Transferencia'),
# (47, 117.89, 'Efectivo'),
# (47, 1451.07, 'Transferencia'),
# (47, 1908.79, 'Transferencia'),
# (47, 337.54, 'Tarjeta'),
# (48, 1035.72, 'Tarjeta'),
# (48, 1704.18, 'Tarjeta'),
# (48, 411.71, 'Transferencia'),
# (48, 1546.62, 'Efectivo'),
# (48, 712.65, 'Transferencia'),
# (48, 1192.48, 'Efectivo'),
# (48, 1270.62, 'Efectivo'),
# (49, 1655.97, 'Efectivo'),
# (49, 1510.0, 'Efectivo'),
# (49, 234.29, 'Transferencia'),
# (49, 1676.76, 'Efectivo'),
# (49, 820.17, 'Efectivo'),
# (49, 1178.24, 'Efectivo'),
# (50, 1667.89, 'Efectivo'),
# (50, 1098.26, 'Transferencia'),
# (50, 573.66, 'Transferencia'),
# (50, 1940.47, 'Efectivo'),
# (50, 913.97, 'Tarjeta'),
# (50, 1070.37, 'Efectivo'),
# (50, 369.17, 'Transferencia'),
# (53, 1180.52, 'Transferencia'),
# (53, 1405.93, 'Efectivo'),
# (53, 617.9, 'Tarjeta'),
# (53, 1435.2, 'Tarjeta'),
# (53, 1116.84, 'Tarjeta'),
# (53, 987.17, 'Transferencia'),
# (53, 1478.02, 'Transferencia'),
# (53, 756.73, 'Efectivo'),
# (53, 357.21, 'Tarjeta'),
# (53, 1647.8, 'Efectivo'),
# (53, 345.89, 'Transferencia'),
# (53, 1863.77, 'Transferencia'),
# (54, 1519.69, 'Efectivo'),
# (54, 801.19, 'Transferencia'),
# (54, 188.64, 'Efectivo'),
# (54, 1422.12, 'Tarjeta'),
# (54, 667.86, 'Tarjeta'),
# (54, 352.04, 'Efectivo'),
# (54, 1025.88, 'Tarjeta'),
# (54, 1939.19, 'Transferencia'),
# (54, 1198.0, 'Transferencia'),
# (54, 264.92, 'Tarjeta'),
# (54, 639.93, 'Efectivo'),
# (56, 541.04, 'Efectivo'),
# (56, 1400.29, 'Tarjeta'),
# (56, 1070.73, 'Efectivo'),
# (56, 1368.49, 'Tarjeta'),
# (56, 682.42, 'Tarjeta'),
# (56, 1281.23, 'Transferencia'),
# (57, 914.23, 'Transferencia'),
# (57, 1302.73, 'Efectivo'),
# (57, 1166.03, 'Transferencia'),
# (57, 1994.05, 'Transferencia'),
# (57, 131.08, 'Transferencia'),
# (57, 1312.78, 'Efectivo'),
# (57, 1572.08, 'Transferencia'),
# (57, 872.05, 'Efectivo'),
# (57, 1926.67, 'Tarjeta'),
# (57, 133.65, 'Transferencia'),
# (57, 1650.99, 'Transferencia'),
# (57, 1842.03, 'Transferencia'),
# (59, 1842.23, 'Transferencia'),
# (59, 1598.57, 'Transferencia'),
# (59, 336.48, 'Efectivo'),
# (59, 229.04, 'Tarjeta'),
# (59, 208.78, 'Tarjeta'),
# (59, 101.58, 'Tarjeta'),
# (59, 1655.29, 'Efectivo'),
# (59, 109.14, 'Efectivo'),
# (60, 929.13, 'Efectivo'),
# (60, 810.85, 'Efectivo'),
# (60, 665.93, 'Tarjeta'),
# (62, 1497.35, 'Transferencia'),
# (62, 1808.45, 'Transferencia'),
# (62, 1365.43, 'Efectivo'),
# (62, 635.45, 'Transferencia'),
# (62, 397.01, 'Efectivo'),
# (62, 194.38, 'Efectivo'),
# (62, 900.29, 'Transferencia'),
# (62, 1946.8, 'Tarjeta'),
# (62, 1425.84, 'Transferencia'),
# (62, 557.88, 'Transferencia'),
# (64, 1926.64, 'Transferencia'),
# (64, 720.53, 'Efectivo'),
# (64, 696.57, 'Efectivo'),
# (64, 1093.29, 'Tarjeta'),
# (64, 1690.92, 'Efectivo'),
# (64, 803.28, 'Tarjeta'),
# (68, 1917.5, 'Efectivo'),
# (68, 150.44, 'Efectivo'),
# (68, 186.2, 'Tarjeta'),
# (68, 1961.74, 'Tarjeta'),
# (68, 299.17, 'Transferencia'),
# (68, 1042.55, 'Transferencia'),
# (68, 830.55, 'Tarjeta'),
# (68, 920.96, 'Efectivo'),
# (70, 1406.32, 'Efectivo'),
# (70, 1826.23, 'Transferencia'),
# (70, 244.6, 'Transferencia'),
# (70, 1169.74, 'Efectivo'),
# (70, 944.23, 'Efectivo'),
# (70, 1998.17, 'Transferencia'),
# (70, 1367.15, 'Transferencia'),
# (70, 1690.75, 'Transferencia'),
# (74, 1819.05, 'Transferencia'),
# (74, 169.12, 'Efectivo'),
# (74, 1725.4, 'Transferencia'),
# (74, 1465.58, 'Efectivo'),
# (74, 1807.11, 'Tarjeta'),
# (74, 1223.12, 'Tarjeta'),
# (74, 1669.94, 'Tarjeta'),
# (74, 1177.98, 'Transferencia'),
# (77, 787.28, 'Transferencia'),
# (77, 630.47, 'Transferencia'),
# (77, 1180.08, 'Tarjeta'),
# (79, 1260.2, 'Transferencia'),
# (79, 1780.94, 'Tarjeta'),
# (79, 1548.07, 'Efectivo'),
# (79, 1182.67, 'Transferencia'),
# (79, 1391.82, 'Efectivo'),
# (79, 814.65, 'Transferencia'),
# (79, 1210.63, 'Efectivo'),
# (79, 1185.78, 'Efectivo'),
# (79, 419.08, 'Tarjeta'),
# (79, 1620.33, 'Efectivo'),
# (79, 463.25, 'Transferencia'),
# (80, 1998.69, 'Transferencia'),
# (80, 658.83, 'Transferencia'),
# (80, 719.41, 'Transferencia'),
# (80, 1819.05, 'Tarjeta'),
# (80, 449.31, 'Efectivo'),
# (80, 828.59, 'Tarjeta'),
# (80, 789.45, 'Transferencia'),
# (80, 252.35, 'Efectivo'),
# (82, 873.54, 'Tarjeta'),
# (82, 785.8, 'Efectivo'),
# (82, 772.63, 'Efectivo'),
# (82, 919.7, 'Tarjeta'),
# (82, 1431.01, 'Efectivo'),
# (82, 474.83, 'Transferencia'),
# (82, 1543.42, 'Tarjeta'),
# (82, 1598.79, 'Transferencia'),
# (82, 266.49, 'Transferencia'),
# (82, 798.52, 'Tarjeta'),
# (83, 988.89, 'Efectivo'),
# (85, 1455.05, 'Tarjeta'),
# (85, 518.61, 'Tarjeta'),
# (85, 1667.84, 'Transferencia'),
# (85, 1455.29, 'Tarjeta'),
# (85, 284.18, 'Tarjeta'),
# (88, 1326.61, 'Efectivo'),
# (88, 394.81, 'Efectivo'),
# (88, 800.35, 'Tarjeta'),
# (88, 820.95, 'Transferencia'),
# (88, 1914.67, 'Transferencia'),
# (88, 573.22, 'Transferencia'),
# (88, 261.96, 'Tarjeta'),
# (88, 101.91, 'Efectivo'),
# (90, 491.16, 'Efectivo'),
# (90, 1137.77, 'Tarjeta'),
# (90, 758.32, 'Transferencia'),
# (90, 1892.61, 'Transferencia'),
# (90, 1036.06, 'Efectivo'),
# (90, 1413.09, 'Transferencia'),
# (90, 158.91, 'Transferencia'),
# (90, 1731.97, 'Efectivo'),
# (91, 1976.94, 'Efectivo'),
# (91, 733.78, 'Efectivo'),
# (91, 1009.64, 'Tarjeta'),
# (91, 1776.9, 'Efectivo'),
# (91, 1148.65, 'Efectivo'),
# (91, 440.34, 'Tarjeta'),
# (91, 1605.37, 'Efectivo'),
# (91, 585.54, 'Tarjeta'),
# (91, 887.77, 'Efectivo'),
# (92, 161.39, 'Efectivo'),
# (92, 1482.06, 'Efectivo'),
# (92, 1413.56, 'Tarjeta'),
# (92, 1306.33, 'Efectivo'),
# (92, 653.16, 'Tarjeta'),
# (93, 948.26, 'Tarjeta'),
# (93, 1527.92, 'Transferencia'),
# (93, 645.55, 'Transferencia'),
# (93, 568.86, 'Transferencia'),
# (93, 775.45, 'Efectivo'),
# (93, 850.95, 'Transferencia'),
# (93, 699.41, 'Efectivo'),
# (93, 1265.03, 'Tarjeta'),
# (93, 900.67, 'Transferencia'),
# (93, 143.51, 'Efectivo'),
# (96, 255.77, 'Transferencia'),
# (96, 596.84, 'Tarjeta'),
# (96, 311.45, 'Transferencia'),
# (96, 1590.4, 'Tarjeta'),
# (96, 462.82, 'Tarjeta'),
# (96, 782.75, 'Transferencia'),
# (96, 1695.43, 'Transferencia'),
# (96, 625.69, 'Tarjeta'),
# (98, 100.6, 'Tarjeta'),
# (98, 1141.08, 'Efectivo'),
# (98, 641.14, 'Transferencia'),
# (98, 1161.83, 'Tarjeta'),
# (98, 644.25, 'Tarjeta'),
# (98, 318.74, 'Efectivo'),
# (98, 561.78, 'Tarjeta'),
# (98, 1410.47, 'Efectivo'),
# (98, 1888.0, 'Transferencia'),
# (98, 688.15, 'Efectivo'),
# (99, 1841.59, 'Efectivo'),
# (99, 311.24, 'Efectivo'),
# (99, 1438.33, 'Tarjeta'),
# (99, 1546.03, 'Transferencia'),
# (99, 835.96, 'Transferencia'),
# (99, 1430.96, 'Transferencia'),
# (100, 521.92, 'Efectivo'),
# (100, 734.52, 'Transferencia'),
# (100, 827.99, 'Efectivo'),
# (100, 1802.93, 'Efectivo'),
# (100, 1129.22, 'Efectivo'),
# (100, 1541.01, 'Efectivo'),
# (100, 660.09, 'Efectivo'),
# (100, 1389.21, 'Transferencia'),
# (100, 1765.57, 'Transferencia'),
# (100, 621.07, 'Efectivo'),
# (100, 870.38, 'Efectivo'),
# (101, 638.68, 'Efectivo'),
# (101, 1639.9, 'Efectivo'),
# (101, 1174.3, 'Efectivo'),
# (101, 1545.76, 'Tarjeta'),
# (101, 1395.86, 'Transferencia'),
# (101, 1292.28, 'Efectivo'),
# (101, 1724.36, 'Efectivo'),
# (102, 640.76, 'Transferencia'),
# (102, 1658.13, 'Transferencia'),
# (102, 811.3, 'Tarjeta'),
# (102, 1575.0, 'Tarjeta'),
# (102, 1417.17, 'Tarjeta'),
# (102, 612.98, 'Tarjeta'),
# (102, 883.33, 'Efectivo'),
# (104, 718.61, 'Tarjeta'),
# (104, 1815.41, 'Efectivo'),
# (104, 1564.81, 'Efectivo'),
# (104, 377.96, 'Transferencia'),
# (105, 1520.6, 'Transferencia'),
# (106, 205.22, 'Tarjeta'),
# (106, 1289.7, 'Efectivo'),
# (106, 1975.67, 'Efectivo'),
# (106, 1269.86, 'Transferencia'),
# (106, 517.7, 'Transferencia'),
# (106, 1350.57, 'Tarjeta'),
# (106, 1315.62, 'Transferencia'),
# (106, 672.49, 'Efectivo'),
# (106, 1060.37, 'Efectivo'),
# (106, 1779.28, 'Tarjeta'),
# (109, 1063.55, 'Tarjeta'),
# (109, 1394.66, 'Efectivo'),
# (109, 1908.38, 'Tarjeta'),
# (109, 268.1, 'Efectivo'),
# (109, 561.48, 'Efectivo'),
# (109, 746.78, 'Transferencia'),
# (111, 1976.12, 'Tarjeta'),
# (111, 1946.76, 'Tarjeta'),
# (111, 1058.13, 'Tarjeta'),
# (111, 1420.44, 'Transferencia'),
# (111, 1829.97, 'Tarjeta'),
# (111, 1783.56, 'Transferencia'),
# (111, 1995.17, 'Efectivo'),
# (111, 290.6, 'Tarjeta'),
# (111, 834.17, 'Efectivo'),
# (111, 1877.17, 'Tarjeta'),
# (111, 518.12, 'Efectivo'),
# (111, 1665.84, 'Efectivo'),
# (115, 1638.97, 'Transferencia'),
# (115, 1974.58, 'Efectivo'),
# (115, 902.05, 'Transferencia'),
# (115, 1439.85, 'Tarjeta'),
# (115, 359.17, 'Tarjeta'),
# (115, 1572.98, 'Efectivo'),
# (115, 1590.92, 'Tarjeta'),
# (115, 1842.33, 'Tarjeta'),
# (115, 1893.34, 'Tarjeta'),
# (115, 544.86, 'Efectivo'),
# (115, 1580.17, 'Transferencia'),
# (117, 512.53, 'Tarjeta'),
# (117, 176.24, 'Transferencia'),
# (117, 1362.38, 'Tarjeta'),
# (117, 466.06, 'Transferencia'),
# (117, 1011.04, 'Transferencia'),
# (117, 328.91, 'Efectivo'),
# (118, 1853.7, 'Tarjeta'),
# (118, 1857.43, 'Transferencia'),
# (118, 1525.29, 'Transferencia'),
# (118, 492.87, 'Efectivo'),
# (118, 1245.54, 'Efectivo'),
# (118, 1284.88, 'Tarjeta'),
# (120, 651.45, 'Efectivo'),
# (120, 604.1, 'Efectivo'),
# (120, 1114.39, 'Efectivo'),
# (120, 787.05, 'Efectivo'),
# (120, 547.81, 'Tarjeta'),
# (120, 236.22, 'Efectivo'),
# (120, 1916.77, 'Tarjeta'),
# (122, 762.43, 'Efectivo'),
# (122, 1944.38, 'Transferencia'),
# (122, 1016.18, 'Efectivo'),
# (122, 378.64, 'Tarjeta'),
# (122, 1574.63, 'Transferencia'),
# (122, 1291.7, 'Tarjeta'),
# (122, 810.19, 'Tarjeta'),
# (122, 858.2, 'Transferencia'),
# (122, 409.73, 'Efectivo'),
# (122, 461.81, 'Efectivo'),
# (122, 238.54, 'Transferencia'),
# (123, 969.13, 'Efectivo'),
# (123, 199.07, 'Tarjeta'),
# (123, 175.69, 'Tarjeta'),
# (123, 1780.01, 'Efectivo'),
# (123, 1840.96, 'Tarjeta'),
# (123, 1555.74, 'Efectivo'),
# (123, 349.66, 'Tarjeta'),
# (123, 768.63, 'Transferencia'),
# (123, 1131.59, 'Efectivo'),
# (123, 1445.33, 'Transferencia'),
# (123, 1490.12, 'Efectivo'),
# (126, 1275.04, 'Transferencia'),
# (126, 1726.24, 'Efectivo'),
# (126, 301.39, 'Tarjeta'),
# (126, 1285.69, 'Transferencia'),
# (126, 841.01, 'Tarjeta'),
# (126, 288.42, 'Transferencia'),
# (126, 238.66, 'Transferencia'),
# (127, 331.58, 'Transferencia'),
# (127, 629.99, 'Tarjeta'),
# (127, 621.46, 'Tarjeta'),
# (127, 1202.67, 'Efectivo'),
# (128, 926.68, 'Efectivo'),
# (128, 570.14, 'Efectivo'),
# (128, 777.47, 'Transferencia'),
# (128, 340.47, 'Efectivo'),
# (129, 199.59, 'Efectivo'),
# (129, 1946.82, 'Efectivo'),
# (129, 1886.2, 'Tarjeta'),
# (129, 1984.6, 'Transferencia'),
# (129, 485.71, 'Transferencia'),
# (129, 1625.91, 'Tarjeta'),
# (129, 1618.66, 'Efectivo'),
# (129, 1141.14, 'Tarjeta'),
# (129, 1970.88, 'Efectivo'),
# (129, 184.83, 'Efectivo'),
# (130, 789.84, 'Efectivo'),
# (130, 1134.46, 'Efectivo'),
# (130, 1370.32, 'Efectivo'),
# (130, 767.25, 'Transferencia'),
# (130, 691.29, 'Tarjeta'),
# (130, 1094.77, 'Efectivo'),
# (130, 1068.17, 'Transferencia'),
# (130, 378.16, 'Transferencia'),
# (130, 1189.53, 'Efectivo'),
# (130, 1069.27, 'Tarjeta'),
# (131, 1279.2, 'Efectivo'),
# (131, 1754.21, 'Tarjeta'),
# (131, 1242.3, 'Transferencia'),
# (131, 1199.65, 'Tarjeta'),
# (131, 1163.29, 'Tarjeta'),
# (132, 836.76, 'Efectivo'),
# (132, 440.24, 'Transferencia'),
# (132, 652.29, 'Transferencia'),
# (132, 1142.16, 'Efectivo'),
# (133, 223.09, 'Transferencia'),
# (133, 1346.02, 'Tarjeta'),
# (133, 586.09, 'Tarjeta'),
# (133, 1416.9, 'Efectivo'),
# (133, 327.43, 'Efectivo'),
# (133, 1091.69, 'Efectivo'),
# (133, 1930.34, 'Efectivo'),
# (133, 201.62, 'Efectivo'),
# (133, 671.82, 'Transferencia'),
# (133, 879.89, 'Transferencia'),
# (133, 1493.01, 'Transferencia'),
# (135, 1001.68, 'Transferencia'),
# (135, 585.75, 'Transferencia'),
# (135, 1218.87, 'Tarjeta'),
# (135, 1820.47, 'Tarjeta'),
# (135, 1604.02, 'Transferencia'),
# (135, 436.37, 'Tarjeta'),
# (135, 517.43, 'Tarjeta'),
# (135, 174.26, 'Transferencia'),
# (135, 661.45, 'Transferencia'),
# (135, 340.16, 'Transferencia'),
# (135, 287.27, 'Transferencia'),
# (136, 1665.46, 'Tarjeta'),
# (136, 726.49, 'Efectivo'),
# (136, 1749.74, 'Tarjeta'),
# (136, 633.78, 'Transferencia'),
# (136, 117.5, 'Tarjeta'),
# (136, 1179.17, 'Tarjeta'),
# (136, 111.4, 'Transferencia'),
# (137, 1524.17, 'Transferencia'),
# (137, 1990.89, 'Transferencia'),
# (137, 1329.24, 'Tarjeta'),
# (137, 1149.96, 'Tarjeta'),
# (137, 803.15, 'Efectivo'),
# (137, 1257.32, 'Tarjeta'),
# (137, 506.98, 'Efectivo'),
# (137, 880.55, 'Tarjeta'),
# (137, 1838.12, 'Tarjeta'),
# (137, 1733.84, 'Transferencia'),
# (137, 519.43, 'Efectivo'),
# (137, 1121.29, 'Transferencia'),
# (138, 127.42, 'Transferencia'),
# (138, 1560.32, 'Tarjeta'),
# (138, 468.35, 'Tarjeta'),
# (138, 1957.49, 'Efectivo'),
# (138, 1574.15, 'Efectivo'),
# (138, 1754.18, 'Efectivo'),
# (143, 1818.36, 'Tarjeta'),
# (143, 810.21, 'Tarjeta'),
# (143, 1964.4, 'Efectivo'),
# (144, 228.64, 'Efectivo'),
# (144, 1592.9, 'Efectivo'),
# (144, 1676.05, 'Efectivo'),
# (144, 874.64, 'Transferencia'),
# (144, 620.84, 'Transferencia'),
# (144, 1917.68, 'Transferencia'),
# (144, 343.75, 'Efectivo'),
# (144, 768.4, 'Efectivo'),
# (145, 676.44, 'Transferencia'),
# (145, 794.96, 'Efectivo'),
# (145, 1454.33, 'Efectivo'),
# (145, 1028.91, 'Transferencia'),
# (145, 994.14, 'Tarjeta'),
# (148, 1491.56, 'Transferencia'),
# (148, 1259.52, 'Transferencia'),
# (148, 1855.46, 'Tarjeta'),
# (148, 477.06, 'Efectivo'),
# (148, 132.31, 'Tarjeta'),
# (148, 486.94, 'Transferencia'),
# (148, 346.75, 'Efectivo'),
# (148, 324.33, 'Transferencia'),
# (148, 1283.38, 'Transferencia'),
# (148, 977.56, 'Efectivo'),
# (149, 1128.56, 'Efectivo'),
# (149, 988.75, 'Efectivo'),
# (151, 813.67, 'Tarjeta'),
# (151, 700.72, 'Efectivo'),
# (151, 1535.66, 'Tarjeta'),
# (151, 695.45, 'Efectivo'),
# (151, 1154.31, 'Efectivo'),
# (151, 1652.97, 'Transferencia'),
# (151, 1783.49, 'Efectivo'),
# (152, 375.12, 'Tarjeta'),
# (152, 1189.69, 'Tarjeta'),
# (152, 1018.69, 'Transferencia'),
# (152, 240.03, 'Efectivo'),
# (152, 989.67, 'Efectivo'),
# (152, 865.21, 'Efectivo'),
# (152, 1405.48, 'Transferencia'),
# (152, 1958.78, 'Efectivo'),
# (152, 1477.29, 'Efectivo'),
# (152, 1272.67, 'Tarjeta'),
# (152, 1466.6, 'Transferencia'),
# (152, 120.79, 'Tarjeta'),
# (154, 680.07, 'Tarjeta'),
# (154, 1008.04, 'Transferencia'),
# (154, 719.41, 'Transferencia'),
# (154, 442.77, 'Efectivo'),
# (154, 731.23, 'Efectivo'),
# (154, 1177.84, 'Transferencia'),
# (155, 1815.26, 'Tarjeta'),
# (155, 1174.1, 'Efectivo'),
# (155, 1289.48, 'Tarjeta'),
# (155, 981.95, 'Efectivo'),
# (155, 1167.73, 'Transferencia'),
# (156, 409.21, 'Transferencia'),
# (159, 1158.51, 'Efectivo'),
# (159, 1546.59, 'Transferencia'),
# (160, 1859.63, 'Transferencia'),
# (160, 1980.41, 'Efectivo'),
# (160, 1870.62, 'Tarjeta'),
# (160, 249.66, 'Tarjeta'),
# (160, 1344.14, 'Transferencia'),
# (160, 1346.5, 'Efectivo'),
# (160, 1267.82, 'Transferencia'),
# (160, 749.78, 'Efectivo'),
# (160, 298.95, 'Efectivo'),
# (160, 1414.52, 'Tarjeta'),
# (161, 1212.01, 'Efectivo'),
# (161, 1681.32, 'Transferencia'),
# (161, 261.57, 'Tarjeta'),
# (161, 152.24, 'Tarjeta'),
# (161, 828.15, 'Tarjeta'),
# (163, 1962.38, 'Transferencia'),
# (163, 929.08, 'Efectivo'),
# (163, 913.72, 'Efectivo'),
# (163, 1137.11, 'Transferencia'),
# (163, 1807.6, 'Efectivo'),
# (163, 1641.15, 'Efectivo'),
# (166, 647.86, 'Transferencia'),
# (166, 1589.04, 'Efectivo'),
# (166, 1729.13, 'Transferencia'),
# (166, 1380.56, 'Efectivo'),
# (166, 1436.98, 'Transferencia'),
# (166, 1595.25, 'Tarjeta'),
# (169, 219.63, 'Efectivo'),
# (169, 555.4, 'Efectivo'),
# (169, 233.43, 'Tarjeta'),
# (169, 1664.09, 'Tarjeta'),
# (169, 1066.16, 'Tarjeta'),
# (170, 1659.26, 'Tarjeta'),
# (170, 459.92, 'Tarjeta'),
# (170, 1988.98, 'Tarjeta'),
# (170, 1591.16, 'Efectivo'),
# (170, 1079.34, 'Efectivo'),
# (170, 335.23, 'Tarjeta'),
# (170, 1820.23, 'Transferencia'),
# (170, 1451.33, 'Tarjeta'),
# (170, 1097.25, 'Efectivo'),
# (170, 1557.9, 'Transferencia'),
# (172, 1022.92, 'Efectivo'),
# (172, 1407.49, 'Tarjeta'),
# (172, 579.84, 'Transferencia'),
# (172, 634.96, 'Tarjeta'),
# (172, 213.83, 'Transferencia'),
# (172, 1313.21, 'Transferencia'),
# (172, 1961.4, 'Tarjeta'),
# (172, 772.99, 'Transferencia'),
# (172, 1097.06, 'Transferencia'),
# (172, 1785.53, 'Tarjeta'),
# (172, 1358.12, 'Efectivo'),
# (172, 335.05, 'Efectivo'),
# (174, 734.64, 'Tarjeta'),
# (174, 113.27, 'Efectivo'),
# (174, 210.97, 'Transferencia'),
# (174, 1642.04, 'Tarjeta'),
# (174, 1691.25, 'Transferencia'),
# (174, 201.56, 'Efectivo'),
# (174, 1767.03, 'Tarjeta'),
# (174, 1957.61, 'Efectivo'),
# (174, 637.85, 'Transferencia'),
# (174, 1752.28, 'Tarjeta'),
# (174, 366.05, 'Tarjeta'),
# (174, 1976.9, 'Transferencia'),
# (175, 117.99, 'Efectivo'),
# (176, 1403.54, 'Efectivo'),
# (176, 1337.03, 'Transferencia'),
# (176, 796.08, 'Transferencia'),
# (176, 622.92, 'Transferencia'),
# (176, 1709.2, 'Transferencia'),
# (176, 1345.12, 'Tarjeta'),
# (180, 462.12, 'Transferencia'),
# (180, 1663.87, 'Tarjeta'),
# (180, 1132.98, 'Tarjeta'),
# (180, 1088.53, 'Efectivo'),
# (180, 1406.77, 'Tarjeta'),
# (180, 667.57, 'Transferencia'),
# (180, 1456.44, 'Tarjeta'),
# (181, 1242.14, 'Efectivo'),
# (181, 462.16, 'Tarjeta'),
# (181, 1406.89, 'Transferencia'),
# (181, 1567.7, 'Tarjeta'),
# (181, 1545.55, 'Transferencia'),
# (181, 1013.72, 'Efectivo'),
# (183, 941.58, 'Efectivo'),
# (183, 1136.94, 'Tarjeta'),
# (183, 1085.1, 'Tarjeta'),
# (183, 1450.94, 'Transferencia'),
# (183, 1868.53, 'Tarjeta'),
# (183, 470.19, 'Tarjeta'),
# (183, 1803.75, 'Efectivo'),
# (183, 943.31, 'Tarjeta'),
# (183, 1768.11, 'Efectivo'),
# (183, 125.53, 'Tarjeta'),
# (183, 705.1, 'Transferencia'),
# (183, 1774.88, 'Efectivo'),
# (184, 1684.21, 'Efectivo'),
# (184, 825.88, 'Transferencia'),
# (184, 666.13, 'Tarjeta'),
# (184, 1001.59, 'Tarjeta'),
# (184, 1785.36, 'Transferencia'),
# (184, 668.03, 'Tarjeta'),
# (184, 518.63, 'Efectivo'),
# (184, 436.6, 'Efectivo'),
# (187, 923.02, 'Efectivo'),
# (187, 1590.37, 'Efectivo'),
# (187, 1856.08, 'Efectivo'),
# (187, 1607.7, 'Tarjeta'),
# (187, 647.45, 'Transferencia'),
# (187, 1781.36, 'Transferencia'),
# (187, 756.2, 'Tarjeta'),
# (187, 1256.93, 'Tarjeta'),
# (187, 531.45, 'Transferencia'),
# (187, 1985.82, 'Tarjeta'),
# (187, 763.92, 'Tarjeta'),
# (189, 689.93, 'Transferencia'),
# (189, 1822.14, 'Tarjeta'),
# (189, 1600.42, 'Transferencia'),
# (189, 1712.52, 'Transferencia'),
# (189, 1861.56, 'Transferencia'),
# (189, 263.7, 'Transferencia'),
# (189, 1911.78, 'Efectivo'),
# (189, 1450.14, 'Efectivo'),
# (189, 1525.69, 'Tarjeta'),
# (189, 1387.46, 'Tarjeta'),
# (189, 1055.31, 'Efectivo'),
# (189, 447.79, 'Tarjeta'),
# (190, 501.6, 'Tarjeta'),
# (190, 610.31, 'Efectivo'),
# (190, 731.73, 'Tarjeta'),
# (190, 1147.85, 'Transferencia'),
# (190, 509.82, 'Efectivo'),
# (190, 505.25, 'Tarjeta'),
# (190, 735.48, 'Tarjeta'),
# (190, 248.47, 'Efectivo'),
# (190, 134.8, 'Transferencia'),
# (190, 1339.32, 'Efectivo'),
# (190, 221.82, 'Efectivo'),
# (190, 509.9, 'Tarjeta'),
# (191, 1543.8, 'Tarjeta'),
# (191, 1823.81, 'Transferencia'),
# (191, 1706.63, 'Tarjeta'),
# (191, 1376.03, 'Efectivo'),
# (191, 862.63, 'Efectivo'),
# (191, 1121.7, 'Efectivo'),
# (191, 1990.42, 'Tarjeta'),
# (191, 1025.34, 'Tarjeta'),
# (191, 1637.38, 'Transferencia'),
# (191, 1060.23, 'Efectivo'),
# (191, 1293.08, 'Transferencia'),
# (193, 428.99, 'Efectivo'),
# (193, 1477.32, 'Tarjeta'),
# (193, 522.09, 'Tarjeta'),
# (193, 1290.57, 'Efectivo'),
# (193, 152.61, 'Efectivo'),
# (193, 1649.14, 'Efectivo'),
# (193, 1721.65, 'Transferencia'),
# (193, 1097.06, 'Transferencia'),
# (193, 1475.31, 'Efectivo'),
# (193, 1844.76, 'Transferencia'),
# (193, 393.55, 'Transferencia'),
# (193, 1721.83, 'Transferencia'),
# (194, 1064.17, 'Tarjeta'),
# (194, 1357.34, 'Tarjeta'),
# (194, 893.72, 'Transferencia'),
# (194, 1766.56, 'Efectivo'),
# (195, 1805.04, 'Transferencia'),
# (195, 404.24, 'Transferencia'),
# (195, 725.43, 'Tarjeta'),
# (195, 1154.32, 'Transferencia'),
# (195, 1703.68, 'Tarjeta'),
# (195, 1561.74, 'Transferencia'),
# (195, 1453.01, 'Tarjeta'),
# (197, 1289.11, 'Transferencia'),
# (199, 351.7, 'Tarjeta'),
# (199, 1504.87, 'Efectivo'),
# (199, 1405.36, 'Tarjeta'),
# (199, 965.17, 'Tarjeta'),
# (199, 265.48, 'Efectivo'),
# (200, 213.34, 'Efectivo'),
# (200, 1290.52, 'Transferencia'),
# (200, 1142.02, 'Tarjeta'),
#
# Tabla 5: Historial crediticio
# (1, 48332.37, 1, 'Regular'),
# (2, 42925.75, 1, 'Regular'),
# (3, 64270.23, 3, 'Regular'),
# (4, 25315.37, 1, 'Bueno'),
# (5, 21528.17, 5, 'Bueno'),
# (6, 1265.15, 2, 'Bueno'),
# (7, 66733.32, 4, 'Bueno'),
# (8, 0, 0, 'Bueno'),
# (9, 71052.17, 1, 'Bueno'),
# (10, 0, 0, 'Bueno'),
# (11, 32089.03, 2, 'Regular'),
# (12, 76897.93, 4, 'Regular'),
# (13, 0, 0, 'Bueno'),
# (14, 25195.78, 2, 'Regular'),
# (15, 0, 0, 'Bueno'),
# (16, 0, 0, 'Bueno'),
# (17, 0, 0, 'Bueno'),
# (18, 93449.97, 5, 'Malo'),
# (19, 20460.42, 4, 'Malo'),
# (20, 0, 0, 'Bueno'),
# (21, 45699.57, 1, 'Bueno'),
# (22, 0, 0, 'Bueno'),
# (23, 62358.0, 3, 'Regular'),
# (24, 0, 0, 'Bueno'),
# (25, 0, 0, 'Bueno'),
# (26, 1410.4, 4, 'Regular'),
# (27, 11102.49, 5, 'Bueno'),
# (28, 86396.68, 5, 'Bueno'),
# (29, 0, 0, 'Bueno'),
# (30, 48050.39, 4, 'Malo'),
# (31, 0, 0, 'Bueno'),
# (32, 32761.6, 4, 'Bueno'),
# (33, 92216.61, 4, 'Regular'),
# (34, 61063.53, 2, 'Bueno'),
# (35, 22240.67, 3, 'Bueno'),
# (36, 0, 0, 'Bueno'),
# (37, 91696.46, 2, 'Regular'),
# (38, 82186.19, 3, 'Regular'),
# (39, 0, 0, 'Bueno'),
# (40, 53764.56, 1, 'Bueno'),
# (41, 17770.95, 4, 'Bueno'),
# (42, 0, 0, 'Bueno'),
# (43, 34146.03, 2, 'Bueno'),
# (44, 35997.02, 1, 'Bueno'),
# (45, 47739.08, 2, 'Bueno'),
# (46, 85397.81, 2, 'Bueno'),
# (47, 4622.9, 3, 'Regular'),
# (48, 0, 0, 'Bueno'),
# (49, 0, 0, 'Bueno'),
# (50, 17659.42, 3, 'Bueno'),
# (51, 47688.19, 4, 'Bueno'),
# (52, 63095.27, 2, 'Malo'),
# (53, 0, 0, 'Bueno'),
# (54, 23025.01, 1, 'Regular'),
# (55, 73718.63, 2, 'Bueno'),
# (56, 53646.62, 3, 'Bueno'),
# (57, 0, 0, 'Bueno'),
# (58, 9385.42, 3, 'Bueno'),
# (59, 31817.33, 2, 'Bueno'),
# (60, 79228.91, 3, 'Regular'),
# (61, 18462.97, 2, 'Bueno'),
# (62, 0, 0, 'Bueno'),
# (63, 31327.04, 5, 'Bueno'),
# (64, 35821.48, 1, 'Malo'),
# (65, 67358.27, 3, 'Bueno'),
# (66, 0, 0, 'Bueno'),
# (67, 58072.33, 4, 'Bueno'),
# (68, 44900.0, 4, 'Bueno'),
# (69, 43877.69, 4, 'Bueno'),
# (70, 66651.55, 2, 'Regular'),
# (71, 44810.8, 4, 'Regular'),
# (72, 28535.05, 1, 'Bueno'),
# (73, 0, 0, 'Bueno'),
# (74, 0, 0, 'Bueno'),
# (75, 7555.76, 2, 'Bueno'),
# (76, 88262.55, 4, 'Bueno'),
# (77, 50185.6, 2, 'Bueno'),
# (78, 43852.99, 2, 'Regular'),
# (79, 0, 0, 'Bueno'),
# (80, 43959.41, 3, 'Bueno'),
# (81, 14404.68, 5, 'Bueno'),
# (82, 83196.74, 2, 'Malo'),
# (83, 87481.87, 4, 'Bueno'),
# (84, 54660.94, 4, 'Regular'),
# (85, 68605.1, 3, 'Bueno'),
# (86, 37354.48, 3, 'Regular'),
# (87, 57579.24, 1, 'Regular'),
# (88, 42304.39, 1, 'Bueno'),
# (89, 88264.29, 2, 'Bueno'),
# (90, 99026.34, 3, 'Bueno'),
# (91, 48613.42, 3, 'Regular'),
# (92, 86385.55, 5, 'Bueno'),
# (93, 87896.26, 1, 'Bueno'),
# (94, 86562.99, 3, 'Regular'),
# (95, 54580.64, 1, 'Regular'),
# (96, 0, 0, 'Bueno'),
# (97, 19660.53, 4, 'Bueno'),
# (98, 73921.92, 4, 'Bueno'),
# (99, 89107.41, 2, 'Bueno'),
# (100, 0, 0, 'Bueno'),
# (101, 94740.0, 4, 'Regular'),
# (102, 0, 0, 'Bueno'),
# (103, 69843.99, 3, 'Regular'),
# (104, 1676.62, 2, 'Regular'),
# (105, 0, 0, 'Bueno'),
# (106, 50834.13, 1, 'Bueno'),
# (107, 57977.83, 3, 'Regular'),
# (108, 36315.08, 2, 'Bueno'),
# (109, 60468.44, 4, 'Bueno'),
# (110, 21537.87, 4, 'Bueno'),
# (111, 0, 0, 'Bueno'),
# (112, 25204.93, 3, 'Bueno'),
# (113, 48543.59, 5, 'Regular'),
# (114, 81471.73, 3, 'Bueno'),
# (115, 64674.76, 5, 'Bueno'),
# (116, 24293.53, 2, 'Bueno'),
# (117, 72136.36, 1, 'Bueno'),
# (118, 88997.13, 1, 'Bueno'),
# (119, 0, 0, 'Bueno'),
# (120, 17345.49, 2, 'Regular'),
# (121, 39682.13, 1, 'Bueno'),
# (122, 0, 0, 'Bueno'),
# (123, 45179.22, 4, 'Bueno'),
# (124, 5787.7, 3, 'Bueno'),
# (125, 83513.21, 1, 'Malo'),
# (126, 18501.11, 4, 'Regular'),
# (127, 67603.67, 3, 'Regular'),
# (128, 38432.0, 2, 'Bueno'),
# (129, 56452.76, 4, 'Bueno'),
# (130, 30906.35, 5, 'Regular'),
# (131, 97373.53, 3, 'Bueno'),
# (132, 42993.72, 4, 'Regular'),
# (133, 86017.03, 4, 'Bueno'),
# (134, 45686.45, 5, 'Bueno'),
# (135, 0, 0, 'Bueno'),
# (136, 91085.86, 1, 'Bueno'),
# (137, 32679.28, 3, 'Bueno'),
# (138, 37404.54, 5, 'Bueno'),
# (139, 87255.74, 2, 'Bueno'),
# (140, 57689.03, 2, 'Bueno'),
# (141, 36362.44, 3, 'Regular'),
# (142, 38238.55, 3, 'Bueno'),
# (143, 85707.99, 3, 'Regular'),
# (144, 91451.68, 3, 'Bueno'),
# (145, 54856.06, 3, 'Malo'),
# (146, 61332.84, 1, 'Bueno'),
# (147, 56265.27, 5, 'Bueno'),
# (148, 0, 0, 'Bueno'),
# (149, 76668.66, 2, 'Malo'),
# (150, 28463.08, 2, 'Bueno'),
# (151, 94098.65, 1, 'Bueno'),
# (152, 98201.74, 1, 'Bueno'),
# (153, 61737.07, 4, 'Bueno'),
# (154, 0, 0, 'Bueno'),
# (155, 37634.91, 1, 'Bueno'),
# (156, 68519.86, 1, 'Regular'),
# (157, 25841.2, 3, 'Regular'),
# (158, 99965.46, 1, 'Regular'),
# (159, 13842.65, 4, 'Regular'),
# (160, 76434.35, 5, 'Bueno'),
# (161, 90492.8, 3, 'Regular'),
# (162, 2337.42, 4, 'Regular'),
# (163, 64640.58, 5, 'Bueno'),
# (164, 0, 0, 'Bueno'),
# (165, 15359.62, 4, 'Bueno'),
# (166, 43624.14, 3, 'Malo'),
# (167, 90574.18, 2, 'Regular'),
# (168, 25254.58, 5, 'Bueno'),
# (169, 79520.29, 2, 'Bueno'),
# (170, 96594.7, 5, 'Regular'),
# (171, 96304.34, 5, 'Malo'),
# (172, 75727.95, 4, 'Bueno'),
# (173, 47737.52, 1, 'Bueno'),
# (174, 27541.6, 5, 'Bueno'),
# (175, 93700.07, 5, 'Bueno'),
# (176, 72359.97, 4, 'Bueno'),
# (177, 39179.76, 1, 'Regular'),
# (178, 39151.97, 2, 'Malo'),
# (179, 84322.14, 3, 'Regular'),
# (180, 17458.42, 4, 'Regular'),
# (181, 34560.36, 1, 'Bueno'),
# (182, 24801.84, 2, 'Regular'),
# (183, 20970.24, 4, 'Malo'),
# (184, 41387.01, 3, 'Bueno'),
# (185, 54216.83, 4, 'Bueno'),
# (186, 0, 0, 'Bueno'),
# (187, 13035.95, 4, 'Regular'),
# (188, 60697.09, 1, 'Regular'),
# (189, 18863.21, 1, 'Malo'),
# (190, 31408.71, 2, 'Bueno'),
# (191, 57924.06, 2, 'Bueno'),
# (192, 95752.96, 5, 'Bueno'),
# (193, 0, 0, 'Bueno'),
# (194, 70555.67, 5, 'Regular'),
# (195, 0, 0, 'Bueno'),
# (196, 2342.83, 5, 'Bueno'),
# (197, 97831.9, 4, 'Bueno'),
# (198, 25314.73, 3, 'Bueno'),
# (199, 64180.97, 3, 'Bueno'),
# (200, 19082.7, 3, 'Regular'),
